# %%
History_file_3M = mr.MesaData('/home/sprasadh/general_3M/general/work/LOGS/history.data')
History_file_3_5M = mr.MesaData('/home/sprasadh/general_3_5M/general/work/LOGS/history.data')
History_file_4M = mr.MesaData('/home/sprasadh/general_4M/general/work/LOGS/history.data')
History_file_4_5M = mr.MesaData('/home/sprasadh/general_4_5M/general/work/LOGS/history.data')
History_file_5M = mr.MesaData('/home/sprasadh/general_5M/general/work/LOGS/history.data')
History_file_5_5M = mr.MesaData('/home/sprasadh/general_5_5M/general/work/LOGS/history.data')
History_file_6M = mr.MesaData('/home/sprasadh/general_6M/work/LOGS/history.data')
History_file_6_5M = mr.MesaData('/home/sprasadh/general_6_5M/general/work/LOGS/history.data')
History_file_7M = mr.MesaData('/home/sprasadh/general_7M_overshooting/general_7.5M/work/LOGS/history.data')
History_file_7_5M = mr.MesaData('/home/sprasadh/general_7_5M/general/work/LOGS/history.data')
History_file_8M = mr.MesaData('/home/sprasadh/general_8M/general_7.5M/work/LOGS/history.data')
History_file_8_5M = mr.MesaData('/home/sprasadh/general_8_5M/general/work/LOGS/history.data')
History_file_9M = mr.MesaData('/home/sprasadh/general_9M/general_7.5M/work/LOGS/history.data')
History_file_9_5M = mr.MesaData('/home/sprasadh/general_9_5M/general/work/LOGS/history.data')
History_file_10M = mr.MesaData('/home/sprasadh/general_10M/general/work/LOGS/history.data')
History_file_10_5M = mr.MesaData('/home/sprasadh/general_10_5M/general/work/LOGS/history.data')
History_file_11M = mr.MesaData('/home/sprasadh/general_11M/general_5M/general/work/LOGS/history.data')
History_file_11_5M = mr.MesaData('/home/sprasadh/general_11_5M/general/work/LOGS/history.data')
History_file_12M = mr.MesaData('/home/sprasadh/general_12M/general/work/LOGS/history.data')
History_file_12_5M = mr.MesaData('/home/sprasadh/general_12_5M/general/work/LOGS/history.data')
History_file_13M = mr.MesaData('/home/sprasadh/general_13M/general/work/LOGS/history.data')


History_file_3_25M = mr.MesaData('/home/sprasadh/general_3_25M/general/work/LOGS/history.data')
History_file_3_75M = mr.MesaData('/home/sprasadh/general_3_75M/general/work/LOGS/history.data')
History_file_4_25M = mr.MesaData('/home/sprasadh/general_4_25M/general/work/LOGS/history.data')
History_file_4_75M = mr.MesaData('/home/sprasadh/general_4_75M/general/work/LOGS/history.data')
History_file_5_25M = mr.MesaData('/home/sprasadh/general_5_25M/general/work/LOGS/history.data')
History_file_5_75M = mr.MesaData('/home/sprasadh/general_5_75M/general/work/LOGS/history.data')
History_file_6_25M = mr.MesaData('/home/sprasadh/general_6_25M/general/work/LOGS/history.data')
History_file_6_75M = mr.MesaData('/home/sprasadh/general_6_75M/general/work/LOGS/history.data')
History_file_7_25M = mr.MesaData('/home/sprasadh/general_7_25M/general/work/LOGS/history.data')
History_file_7_75M = mr.MesaData('/home/sprasadh/general_7_75M/general/work/LOGS/history.data')
History_file_8_25M = mr.MesaData('/home/sprasadh/general_8_25M/general/work/LOGS/history.data')
History_file_8_75M = mr.MesaData('/home/sprasadh/general_8_75M/general/work/LOGS/history.data')
History_file_9_25M = mr.MesaData('/home/sprasadh/general_9_25M/general/work/LOGS/history.data')
History_file_9_75M = mr.MesaData('/home/sprasadh/general_9_75M/general/work/LOGS/history.data')
History_file_10_25M = mr.MesaData('/home/sprasadh/general_10_25M/general/work/LOGS/history.data')
History_file_10_75M = mr.MesaData('/home/sprasadh/general_10_75M/general/work/LOGS/history.data')
History_file_11_25M = mr.MesaData('/home/sprasadh/general_11_25M/general/work/LOGS/history.data')
History_file_11_75M = mr.MesaData('/home/sprasadh/general_11_75M/general/work/LOGS/history.data')
History_file_12_25M = mr.MesaData('/home/sprasadh/general_12_25M/general/work/LOGS/history.data')
History_file_12_75M = mr.MesaData('/home/sprasadh/general_12_75M/general/work/LOGS/history.data')
    Merger

Merger_4_75_to_8M = mr.MesaData('/home/sprasadh/Merger_models/RW_Cam/4_75_to_8/general/work/LOGS/history.data')
Merger_4_25_to_8M = mr.MesaData('/home/sprasadh/Merger_models/RW_Cam/4_25_to_8M/general/work/LOGS/history.data')
Merger_4_5_to_8M = mr.MesaData('/home/sprasadh/Merger_models/RW_Cam/4_5_to_8M/general/work/LOGS/history.data')
Merger_4_to_8M = mr.MesaData('/home/sprasadh/Merger_models/RW_Cam/4_to_8M/general/work/LOGS/history.data')
Merger_temp_4_75_to_8M = Merger_4_75_to_8M.data('Teff')
Merger_temp_4_75_to_8M = np.log10(Merger_temp_4_75_to_8M)
Merger_Lum_4_75_to_8M = Merger_4_75_to_8M.data('log_L')
Merger_ages_4_75_to_8M = Merger_4_75_to_8M.data('star_age')

Merger_temp_4_25_to_8M = Merger_4_25_to_8M.data('Teff')
Merger_temp_4_25_to_8M = np.log10(Merger_temp_4_25_to_8M)
Merger_Lum_4_25_to_8M = Merger_4_25_to_8M.data('log_L')
Merger_ages_4_25_to_8M = Merger_4_25_to_8M.data('star_age')

Merger_temp_4_5_to_8M = Merger_4_5_to_8M.data('Teff')
Merger_temp_4_5_to_8M = np.log10(Merger_temp_4_5_to_8M)
Merger_Lum_4_5_to_8M = Merger_4_5_to_8M.data('log_L')
Merger_ages_4_5_to_8M = Merger_4_5_to_8M.data('star_age')

Merger_temp_4_to_8M = Merger_4_to_8M.data('Teff')
Merger_temp_4_to_8M = np.log10(Merger_temp_4_to_8M)
Merger_Lum_4_to_8M = Merger_4_to_8M.data('log_L')
Merger_ages_4_to_8M = Merger_4_to_8M.data('star_age')

    Normal tracks
temp_3M = History_file_3M.data('Teff')
temp_3M = np.log10(temp_3M)
Lum_3M = (History_file_3M.data('log_L'))
ages_3_5M = History_file_3_5M.data('star_age')
temp_3_5M = History_file_3_5M.data('Teff')
temp_3_5M = np.log10(temp_3_5M)
Lum_3_5M = History_file_3_5M.data('log_L')
temp_3_25M = History_file_3_25M.data('Teff')
temp_3_25M = np.log10(temp_3_25M)
Lum_3_25M = History_file_3_25M.data('log_L')
temp_3_75M = History_file_3_75M.data('Teff')
temp_3_75M = np.log10(temp_3_75M)
Lum_3_75M = History_file_3_75M.data('log_L')

ages_3_M = History_file_3M.data('star_age')
ages_3_25M = History_file_3_25M.data('star_age')
ages_3_5M = History_file_3_5M.data('star_age')
ages_3_75M = History_file_3_75M.data('star_age')

temp_4M = History_file_4M.data('Teff')
temp_4M = np.log10(temp_4M)
Lum_4M = (History_file_4M.data('log_L'))
ages_4_5M = History_file_4_5M.data('star_age')
temp_4_5M = History_file_4_5M.data('Teff')
temp_4_5M = np.log10(temp_4_5M)
Lum_4_5M = History_file_4_5M.data('log_L')
temp_4_25M = History_file_4_25M.data('Teff')
temp_4_25M = np.log10(temp_4_25M)
Lum_4_25M = History_file_4_25M.data('log_L')
temp_4_75M = History_file_4_75M.data('Teff')
temp_4_75M = np.log10(temp_4_75M)
Lum_4_75M = History_file_4_75M.data('log_L')

ages_4_M = History_file_4M.data('star_age')
ages_4_25M = History_file_4_25M.data('star_age')
ages_4_5M = History_file_4_5M.data('star_age')
ages_4_75M = History_file_4_75M.data('star_age')


ages_5M = History_file_5M.data('star_age')
temp_5M = History_file_5M.data('Teff')
temp_5M = np.log10(temp_5M)
Lum_5M = History_file_5M.data('log_L')
ages_5_5M = History_file_5_5M.data('star_age')
temp_5_5M = History_file_5_5M.data('Teff')
temp_5_5M = np.log10(temp_5_5M)
Lum_5_5M = History_file_5_5M.data('log_L')
temp_5_25M = History_file_5_25M.data('Teff')
temp_5_25M = np.log10(temp_5_25M)
Lum_5_25M = History_file_5_25M.data('log_L')
temp_5_75M = History_file_5_75M.data('Teff')
temp_5_75M = np.log10(temp_5_75M)
Lum_5_75M = History_file_5_75M.data('log_L')

ages_5_M = History_file_5M.data('star_age')
ages_5_25M = History_file_5_25M.data('star_age')
ages_5_5M = History_file_5_5M.data('star_age')
ages_5_75M = History_file_5_75M.data('star_age')

ages_6M = History_file_6M.data('star_age')
temp_6M = History_file_6M.data('Teff')
temp_6M = np.log10(temp_6M)
Lum_6M = (History_file_6M.data('log_L'))
ages_6_5M = History_file_6_5M.data('star_age')
temp_6_5M = History_file_6_5M.data('Teff')
temp_6_5M = np.log10(temp_6_5M)
Lum_6_5M = History_file_6_5M.data('log_L')
temp_6_25M = History_file_6_25M.data('Teff')
temp_6_25M = np.log10(temp_6_25M)
Lum_6_25M = History_file_6_25M.data('log_L')
temp_6_75M = History_file_6_75M.data('Teff')
temp_6_75M = np.log10(temp_6_75M)
Lum_6_75M = History_file_6_75M.data('log_L')

ages_6_M = History_file_6M.data('star_age')
ages_6_25M = History_file_6_25M.data('star_age')
ages_6_5M = History_file_6_5M.data('star_age')
ages_6_75M = History_file_6_75M.data('star_age')

ages_7M = History_file_7M.data('star_age')
temp_7M = History_file_7M.data('Teff')
temp_7M = np.log10(temp_7M)
Lum_7M = (History_file_7M.data('log_L'))
ages_7_5M = History_file_7_5M.data('star_age')
temp_7_5M = History_file_7_5M.data('Teff')
temp_7_5M = np.log10(temp_7_5M)
Lum_7_5M = History_file_7_5M.data('log_L')
temp_7_25M = History_file_7_25M.data('Teff')
temp_7_25M = np.log10(temp_7_25M)
Lum_7_25M = History_file_7_25M.data('log_L')
temp_7_75M = History_file_7_75M.data('Teff')
temp_7_75M = np.log10(temp_7_75M)
Lum_7_75M = History_file_7_75M.data('log_L')

ages_7_M = History_file_7M.data('star_age')
ages_7_25M = History_file_7_25M.data('star_age')
ages_7_5M = History_file_7_5M.data('star_age')
ages_7_75M = History_file_7_75M.data('star_age')

ages_8M = History_file_8M.data('star_age')
temp_8M = History_file_8M.data('Teff')
temp_8M = np.log10(temp_8M)
Lum_8M = (History_file_8M.data('log_L'))
ages_8_5M = History_file_8_5M.data('star_age')
temp_8_5M = History_file_8_5M.data('Teff')
temp_8_5M = np.log10(temp_8_5M)
Lum_8_5M = History_file_8_5M.data('log_L')
temp_8_25M = History_file_8_25M.data('Teff')
temp_8_25M = np.log10(temp_8_25M)
Lum_8_25M = History_file_8_25M.data('log_L')
temp_8_75M = History_file_8_75M.data('Teff')
temp_8_75M = np.log10(temp_8_75M)
Lum_8_75M = History_file_8_75M.data('log_L')

ages_8_M = History_file_8M.data('star_age')
ages_8_25M = History_file_8_25M.data('star_age')
ages_8_5M = History_file_8_5M.data('star_age')
ages_8_75M = History_file_8_75M.data('star_age')

ages_9M = History_file_9M.data('star_age')
temp_9M = History_file_9M.data('Teff')
temp_9M = np.log10(temp_9M)
Lum_9M = (History_file_9M.data('log_L'))
ages_9_5M = History_file_9_5M.data('star_age')
temp_9_5M = History_file_9_5M.data('Teff')
temp_9_5M = np.log10(temp_9_5M)
Lum_9_5M = History_file_9_5M.data('log_L')
temp_9_25M = History_file_9_25M.data('Teff')
temp_9_25M = np.log10(temp_9_25M)
Lum_9_25M = History_file_9_25M.data('log_L')
temp_9_75M = History_file_9_75M.data('Teff')
temp_9_75M = np.log10(temp_9_75M)
Lum_9_75M = History_file_9_75M.data('log_L')

ages_9_M = History_file_9M.data('star_age')
ages_9_25M = History_file_9_25M.data('star_age')
ages_9_5M = History_file_9_5M.data('star_age')
ages_9_75M = History_file_9_75M.data('star_age')

ages_10M = History_file_10M.data('star_age')
temp_10M = History_file_10M.data('Teff')
temp_10M = np.log10(temp_10M)
Lum_10M = (History_file_10M.data('log_L'))
temp_10_5M = History_file_10_5M.data('Teff')
temp_10_5M = np.log10(temp_10_5M)
Lum_10_5M = History_file_10_5M.data('log_L')
temp_10_25M = History_file_10_25M.data('Teff')
temp_10_25M = np.log10(temp_10_25M)
Lum_10_25M = History_file_10_25M.data('log_L')
temp_10_75M = History_file_10_75M.data('Teff')
temp_10_75M = np.log10(temp_10_75M)
Lum_10_75M = History_file_10_75M.data('log_L')

ages_10_M = History_file_10M.data('star_age')
ages_10_25M = History_file_10_25M.data('star_age')
ages_10_5M = History_file_10_5M.data('star_age')
ages_10_75M = History_file_10_75M.data('star_age')

ages_11M = History_file_11M.data('star_age')
temp_11M = History_file_11M.data('Teff')
temp_11M = np.log10(temp_11M)
Lum_11M = (History_file_11M.data('log_L'))
ages_11_5M = History_file_11_5M.data('star_age')
temp_11_5M = History_file_11_5M.data('Teff')
temp_11_5M = np.log10(temp_11_5M)
Lum_11_5M = History_file_11_5M.data('log_L')
temp_11_25M = History_file_11_25M.data('Teff')
temp_11_25M = np.log10(temp_11_25M)
Lum_11_25M = History_file_11_25M.data('log_L')
temp_11_75M = History_file_11_75M.data('Teff')
temp_11_75M = np.log10(temp_11_75M)
Lum_11_75M = History_file_11_75M.data('log_L')

ages_11_M = History_file_11M.data('star_age')
ages_11_25M = History_file_11_25M.data('star_age')
ages_11_5M = History_file_11_5M.data('star_age')
ages_11_75M = History_file_11_75M.data('star_age')

ages_12M = History_file_12M.data('star_age')
temp_12M = History_file_12M.data('Teff')
temp_12M = np.log10(temp_12M)
Lum_12M = (History_file_12M.data('log_L'))
ages_12_5M = History_file_12_5M.data('star_age')
temp_12_5M = History_file_12_5M.data('Teff')
temp_12_5M = np.log10(temp_12_5M)
Lum_12_5M = History_file_12_5M.data('log_L')
temp_12_25M = History_file_12_25M.data('Teff')
temp_12_25M = np.log10(temp_12_25M)
Lum_12_25M = History_file_11_25M.data('log_L')
temp_12_75M = History_file_11_75M.data('Teff')
temp_12_75M = np.log10(temp_11_75M)
Lum_12_75M = History_file_12_75M.data('log_L')

ages_12_M = History_file_12M.data('star_age')
ages_12_25M = History_file_12_25M.data('star_age')
ages_12_5M = History_file_12_5M.data('star_age')
ages_12_75M = History_file_12_75M.data('star_age')

ages_13M = History_file_13M.data('star_age')
temp_13M = History_file_13M.data('Teff')
temp_13M = np.log10(temp_13M)
Lum_13M = (History_file_13M.data('log_L'))

ages_13_M = History_file_13M.data('star_age')

P_KN = 34.029641
P_SV = 11.129318
P_RW = 16.414812

B_V_KN = 1.58
B_V_RW = 1.35
B_V_SV = 1.04

del_B_V = 0.02
    Companion temperature
B_V_CKN = -0.14
B_V_CRW = -0.08
B_V_CSV = -0.09

T_eff_CSV = 4.10
T_eff_CRW = 4.09
T_eff_CKN = 4.16


del_T_CSV = 0.005*T_eff_CSV
del_T_CRW = 0.005*T_eff_CRW
del_T_CKN = 0.005*T_eff_CKN
fie_SV = 0.716+ (0.225*B_V_SV)
fie_RW = 0.716+ (0.225*B_V_RW)
fie_KN = 0.716+ (0.225*B_V_KN)
del_fie_SV =  0.015+ (B_V_SV*0.017) + del_B_V*(0.225)
del_fie_RW =  0.015+ (B_V_RW*0.017) + del_B_V*(0.225)
del_fie_KN =  0.015+ (B_V_KN*0.017) + del_B_V*(0.225)
T_eff_SV = np.log10(5040/fie_SV)
T_eff_RW = np.log10(5040/fie_RW)
T_eff_KN = np.log10(5040/fie_KN)
del_T_SV_1= (del_fie_SV/fie_SV**2)
del_T_RW_1 = (del_fie_RW/fie_RW**2)
del_T_KN_1 = (del_fie_KN/fie_KN**2)
del_T_SV= (del_fie_SV/fie_SV**2)/T_eff_SV
del_T_RW = (del_fie_RW/fie_RW**2)/T_eff_RW
del_T_KN = (del_fie_KN/fie_KN**2)/T_eff_KN
a = -2.715
b = -4.153
P_SV = 11.1
P_RW = 16.2
P_KN = 34.4
M_v_SV = a*(np.log10(P_SV)-(np.log10(10))) + b
M_v_RW = a*(np.log10(P_RW)-(np.log10(10))) + b
M_v_KN = a*(np.log10(P_KN)-(np.log10(10))) + b
BC_SV = -0.161
BC_RW = -0.232
BC_KN = -0.161
del_P = 0.0001
M_bol_SV = M_v_SV + BC_SV
M_bol_RW = M_v_RW + BC_RW
M_bol_KN = M_v_KN + BC_KN
# del_L_SV = np.sqrt((a*(del_P/P_SV)**2)+((0.060)**2))/2.5
# del_L_RW = np.sqrt((a*(del_P/P_RW)**2)+((0.060)**2))
# del_L_KN = np.sqrt((a*(del_P/P_KN)**2)+((0.060)**2))/2.5
L_SV = (4.8-M_bol_SV)/2.5
L_RW = (4.8-M_bol_RW)/2.5
L_KN = (4.8-M_bol_KN)/2.5
del_beta = 0.060

del_Mv_SV = a*(del_P/P_SV) + del_beta
del_Mv_RW = a*(del_P/P_RW) + del_beta
del_Mv_KN = a*(del_P/P_KN) + del_beta

del_L_SV = (-M_bol_SV*del_Mv_SV)/2.5
del_L_RW = (-M_bol_RW*del_Mv_RW)/2.5
del_L_KN = (-M_bol_KN*del_Mv_KN)/2.5
    Companion Luminosity
L_CSV = 2.99
L_CRW = 3.11
L_CKN = 3.43
del_L_CSV = 0.02*L_CSV 
del_L_CRW = 0.02*L_CRW
del_L_CKN = 0.02*L_CKN
fig, axes = plt.subplots()
fig.set_figwidth(26)
fig.set_figheight(16)

# ##Tracks
# ##Tracks
plt.plot(temp_10M,Lum_10M,color ='orange')
plt.plot(temp_9M,Lum_9M ,color ='orange')
plt.plot(temp_8M,Lum_8M,color = 'orange')
plt.plot(temp_5M,Lum_5M ,color ='orange')

# plt.plot(temp_10_5M,Lum_10_5M,color ='w')         ## 5 Crossings
plt.plot(temp_9_5M,Lum_9_5M ,color ='y')
plt.plot(temp_8_5M,Lum_8_5M ,color ='y')
plt.plot(temp_7_5M,Lum_7_5M ,color ='y')


plt.plot(temp_5_25M,Lum_5_25M ,color ='g')
plt.plot(temp_8_25M,Lum_8_25M ,color ='g')
plt.plot(temp_9_25M,Lum_9_25M ,color ='g')
plt.plot(temp_10_25M,Lum_10_25M ,color ='g')

plt.plot(temp_4_75M,Lum_4_75M ,color ='teal')
plt.plot(temp_7_75M,Lum_7_75M ,color ='teal')
plt.plot(temp_8_75M,Lum_8_75M ,color ='teal')
plt.plot(temp_9_75M,Lum_9_75M ,color ='teal')

#########Instability Strip
blue_left_edge = [3.91,3.76]
blue_right_edge = [2.4,4.5]
red_left_edge = [3.79,3.65]
red_right_edge = [2.4,4.5]

plt.plot(blue_left_edge,blue_right_edge, 'b')
plt.plot(red_left_edge,red_right_edge, 'r')
plt.gca().invert_xaxis()



#######Companion
# plt.plot(T_eff_CSV, L_CSV, marker = 'X',color = 'pink')
plt.plot(T_eff_CRW, L_CRW, '^',color = 'w')
# plt.plot(T_eff_CKN, L_CKN, 'P',color = 'linen')
# plt.errorbar(T_eff_CSV,L_CSV, xerr = del_T_CSV ,yerr= del_L_CSV, ecolor='pink')
plt.errorbar(T_eff_CRW,L_CRW, xerr = del_T_CRW ,yerr= del_L_CRW, ecolor='w', elinewidth= 4)
# plt.errorbar(T_eff_CKN,L_CKN, xerr = del_T_CKN ,yerr= del_L_CKN, ecolor='linen')



#######Cepheid
# plt.plot(T_eff_SV,L_SV, 'X',color = 'pink', label = 'SV Per')
plt.plot(T_eff_RW,L_RW, '^',color = 'w', label = 'RW Cam ')
# plt.plot(T_eff_KN,L_KN, 'P',color = 'linen', label = 'KN Cen ')

# plt.errorbar(T_eff_SV,L_SV, xerr = del_T_SV ,yerr= del_L_SV, ecolor='pink')
plt.errorbar(T_eff_RW,L_RW, xerr = del_T_RW ,yerr= del_L_RW, ecolor='w' , elinewidth=6)
# plt.errorbar(T_eff_KN,L_KN, xerr = del_T_KN ,yerr= del_L_KN, ecolor='linen')

#####Labels
plt.xlabel('Log T_eff (K)' ,color = 'w' , fontsize = 24)
plt.ylabel('Log L (Solar Luminosity)',color = 'w', fontsize = 24)
plt.tick_params(axis = 'x' ,colors = 'w')
plt.tick_params(axis = 'y' ,colors = 'w')
axes.set_facecolor("Black")
fig.set_facecolor('k')
# plt.title('Cep evolution ',color = 'white')
# plt.legend(loc = 'upper left')

plt.xticks(fontsize = 22);
plt.yticks(fontsize = 22);

# plt.xlim(4,3.6)
# plt.ylim(3.5,3.75)
    Age - Companion

min_4_75left_CRW = np.argmin(np.abs(temp_4_75M - (T_eff_CRW + del_T_CRW))) 
Age_4_75left_CRW = ages_4_75M[min_4_75left_CRW]

min_4_75right_CRW = np.argmin(np.abs(temp_4_75M - (T_eff_CRW - del_T_CRW))) 
Age_4_75right_CRW = ages_4_75M[min_4_75right_CRW]

print(Age_4_75left_CRW)
print(Age_4_75right_CRW)
min_5left_CRW = np.argmin(np.abs(temp_5M - (T_eff_CRW + del_T_CRW))) 
Age_5left_CRW = ages_5M[min_5left_CRW]

min_5right_CRW = np.argmin(np.abs(temp_5M - (T_eff_CRW - del_T_CRW))) 
Age_5right_CRW = ages_5M[min_5right_CRW]

print(Age_5left_CRW)
print(Age_5right_CRW)
min_5_25left_CRW = np.argmin(np.abs(temp_5_25M - (T_eff_CRW + del_T_CRW))) 
Age_5_25left_CRW = ages_5_25M[min_5_25left_CRW]

min_5_25right_CRW = np.argmin(np.abs(temp_5_25M - (T_eff_CRW - del_T_CRW))) 
Age_5_25right_CRW = ages_5_25M[min_5_25right_CRW]

print(Age_5_25left_CRW)
print(Age_5_25right_CRW)
    Companion- Needed Age
NA_min_8left_CRW = np.argmin(np.abs(temp_8M - (T_eff_CRW + del_T_CRW))) 
NA_Age_8left_CRW = ages_8M[NA_min_8left_CRW]

NA_min_8right_CRW = np.argmin(np.abs(temp_8M - (T_eff_CRW - del_T_CRW))) 
NA_Age_8right_CRW = ages_8M[NA_min_8right_CRW]

print(NA_Age_8left_CRW)
print(NA_Age_8right_CRW)
NA_min_7_75left_CRW = np.argmin(np.abs(temp_7_75M - (T_eff_CRW + del_T_CRW))) 
NA_Age_7_75left_CRW = ages_7_75M[NA_min_7_75left_CRW]

NA_min_7_75right_CRW = np.argmin(np.abs(temp_7_75M - (T_eff_CRW - del_T_CRW))) 
NA_Age_7_75right_CRW = ages_7_75M[NA_min_7_75right_CRW]

print(NA_Age_7_75left_CRW)
print(NA_Age_7_75right_CRW)
NA_min_7_5left_CRW = np.argmin(np.abs(temp_7_5M - (T_eff_CRW + del_T_CRW))) 
NA_Age_7_5left_CRW = ages_7_5M[NA_min_7_5left_CRW]

NA_min_7_5right_CRW = np.argmin(np.abs(temp_7_5M - (T_eff_CRW - del_T_CRW))) 
NA_Age_7_5right_CRW = ages_7_5M[NA_min_7_5right_CRW]

print(NA_Age_7_5left_CRW)
print(NA_Age_7_5right_CRW)
min_7left_CRW = np.argmin(np.abs(temp_7M - (T_eff_CRW + del_T_CRW))) 
Age_7left_CRW = ages_7M[min_7left_CRW]

min_7right_CRW = np.argmin(np.abs(temp_7M - (T_eff_CRW - del_T_CRW))) 
Age_7right_CRW = ages_7M[min_7right_CRW]

print(Age_7left_CRW)
print(Age_7right_CRW)
    Age- Cepheid
Blue_loop_7_5_RW = int(len(temp_7_5M)*(0.6))
min_7_5left_RW = Blue_loop_7_5_RW + np.argmin(np.abs(temp_7_5M[Blue_loop_7_5_RW:] - (T_eff_RW + del_T_RW))) 
Age_7_5left_RW = ages_7_5M[min_7_5left_RW]

min_7_5right_RW = Blue_loop_7_5_RW + np.argmin(np.abs(temp_7_5M[Blue_loop_7_5_RW:] - (T_eff_RW - del_T_RW))) 
Age_7_5right_RW = ages_7_5M[min_7_5right_RW]

print(Age_7_5left_RW)
print(Age_7_5right_RW)
Blue_loop_8_RW = int(len(temp_8M)*(0.6))

min_8left_RW = Blue_loop_8_RW + np.argmin(np.abs(temp_8M[Blue_loop_8_RW:] - (T_eff_RW + del_T_RW))) 
Age_8left_RW = ages_8M[min_8left_RW]

min_8right_RW = Blue_loop_8_RW +np.argmin(np.abs(temp_8M[Blue_loop_8_RW:] - (T_eff_RW - del_T_RW))) 
Age_8right_RW = ages_8M[min_8right_RW]

print(Age_8left_RW)
print(Age_8right_RW)
Blue_loop_8_25_RW = int(len(temp_8_25M)*(0.6))
min_8_25left_RW = Blue_loop_8_25_RW + np.argmin(np.abs(temp_8_25M[Blue_loop_8_25_RW:] - (T_eff_RW + del_T_RW))) 
Age_8_25left_RW = ages_8_25M[min_8_25left_RW]

min_8_25right_RW = Blue_loop_8_25_RW + np.argmin(np.abs(temp_8_25M[Blue_loop_8_25_RW:] - (T_eff_RW - del_T_RW))) 
Age_8_25right_RW = ages_8_25M[min_8_25right_RW]

print(Age_8_25left_RW)
print(Age_8_25right_RW)
Blue_loop_7_75_RW = int(len(temp_7_75M)*(0.6))
min_7_75left_RW = Blue_loop_7_75_RW + np.argmin(np.abs(temp_7_75M[Blue_loop_7_75_RW:] - (T_eff_RW + del_T_RW))) 
Age_7_75left_RW = ages_7_75M[min_7_75left_RW]

min_7_75right_RW = Blue_loop_7_75_RW + np.argmin(np.abs(temp_7_75M[Blue_loop_7_75_RW:] - (T_eff_RW - del_T_RW))) 
Age_7_75right_RW = ages_7_75M[min_7_75right_RW]

print(Age_7_75left_RW)
print(Age_7_75right_RW)
First_crossing_9_75M_RW = int(len(temp_9_75M)*(0.4))

min_9_75left_RW = np.argmin(np.abs(temp_9_75M[0:First_crossing_9_75M_RW] - (T_eff_RW + del_T_RW))) 
Age_9_75left_RW = ages_9_75M[min_9_75left_RW]

min_9_75right_RW = np.argmin(np.abs(temp_9_75M[0:First_crossing_9_75M_RW] - (T_eff_RW - del_T_RW))) 
Age_9_75right_RW = ages_9_75M[min_9_75right_RW]

print(Age_9_75left_RW)
print(Age_9_75right_RW)
First_crossing_10M_RW = int(len(temp_10M)*(0.4))

min_10left_RW = np.argmin(np.abs(temp_10M[0:First_crossing_10M_RW] - (T_eff_RW + del_T_RW))) 
Age_10left_RW = ages_10M[min_10left_RW]

min_10right_RW = np.argmin(np.abs(temp_10M[0:First_crossing_10M_RW] - (T_eff_RW - del_T_RW))) 
Age_10right_RW = ages_10M[min_10right_RW]

print(Age_10left_RW)
print(Age_10right_RW)
First_crossing_10_25M_RW = int(len(temp_10_25M)*(0.4))

min_10_25left_RW = np.argmin(np.abs(temp_10_25M[0:First_crossing_10_25M_RW] - (T_eff_RW + del_T_RW))) 
Age_10_25left_RW = ages_10_25M[min_10_25left_RW]

min_10_25right_RW = np.argmin(np.abs(temp_10_25M[0:First_crossing_10_25M_RW] - (T_eff_RW - del_T_RW))) 
Age_10_25right_RW = ages_10_25M[min_10_25right_RW]

print(Age_10_25left_RW)
print(Age_10_25right_RW)
    Isochrone
    
Upper limit for this is mass of the cepheid we are trying to match.
ISC_3M_for_8 = np.argmin(np.abs(ages_3_M - Age_8left_RW))
ISC_4M_for_8 = np.argmin(np.abs(ages_4_M - Age_8left_RW))
ISC_5M_for_8 = np.argmin(np.abs(ages_5_M - Age_8left_RW))
ISC_6M_for_8 = np.argmin(np.abs(ages_6_M - Age_8left_RW))
ISC_7M_for_8 = np.argmin(np.abs(ages_7_M - Age_8left_RW))
ISC_8M_for_8 = np.argmin(np.abs(ages_8_M - Age_8left_RW))
# ISC_9M_for_8 = np.argmin(np.abs(ages_9_M - Age_8left_RW))
# ISC_10M_for_8 = np.argmin(np.abs(ages_10_M - Age_8left_RW))
# ISC_11M_for_8 = np.argmin(np.abs(ages_11_M - Age_8left_RW))
# ISC_12M_for_8 = np.argmin(np.abs(ages_12_M - Age_8left_RW))

ages_8_M[ISC_8M_for_8]
Age_8left_RW
ages_8_M[ISC_8M_for_8]
temp_8M[ISC_8M_for_8]
Lum_8M[ISC_8M_for_8]
fig, axes = plt.subplots()
fig.set_figwidth(26)
fig.set_figheight(16)

# ##Tracks
# ##Tracks
plt.plot(temp_10M,Lum_10M,color ='orange')
plt.plot(temp_9M,Lum_9M ,color ='orange')
plt.plot(temp_8M,Lum_8M,color = 'orange')
plt.plot(temp_5M,Lum_5M ,color ='orange')

# plt.plot(temp_10_5M,Lum_10_5M,color ='w')         ## 5 Crossings
plt.plot(temp_9_5M,Lum_9_5M ,color ='y')
plt.plot(temp_8_5M,Lum_8_5M ,color ='y')


plt.plot(temp_5_25M,Lum_5_25M ,color ='g')
plt.plot(temp_8_25M,Lum_8_25M ,color ='g')
plt.plot(temp_9_25M,Lum_9_25M ,color ='g')
plt.plot(temp_10_25M,Lum_10_25M ,color ='g')

plt.plot(temp_4_75M,Lum_4_75M ,color ='teal')
plt.plot(temp_8_75M,Lum_8_75M ,color ='teal')
plt.plot(temp_9_75M,Lum_9_75M ,color ='teal')

#########Instability Strip
blue_left_edge = [3.91,3.76]
blue_right_edge = [2.4,4.5]
red_left_edge = [3.79,3.65]
red_right_edge = [2.4,4.5]

plt.plot(blue_left_edge,blue_right_edge, 'b')
plt.plot(red_left_edge,red_right_edge, 'r')
plt.gca().invert_xaxis()



#######Companion
plt.plot(T_eff_CSV, L_CSV, marker = 'X',color = 'pink')
plt.plot(T_eff_CRW, L_CRW, '^',color = 'cyan')
plt.plot(T_eff_CKN, L_CKN, 'P',color = 'linen')
# plt.errorbar(T_eff_CSV,L_CSV, xerr = del_T_CSV ,yerr= del_L_CSV, ecolor='pink')
plt.errorbar(T_eff_CRW,L_CRW, xerr = del_T_CRW ,yerr= del_L_CRW, ecolor='cyan')
# plt.errorbar(T_eff_CKN,L_CKN, xerr = del_T_CKN ,yerr= del_L_CKN, ecolor='linen')



#######Cepheid
plt.plot(T_eff_SV,L_SV, 'X',color = 'pink', label = 'SV Per')
plt.plot(T_eff_RW,L_RW, '^',color = 'cyan', label = 'RW Cam ')
plt.plot(T_eff_KN,L_KN, 'P',color = 'linen', label = 'KN Cen ')

# plt.errorbar(T_eff_SV,L_SV, xerr = del_T_SV ,yerr= del_L_SV, ecolor='pink')
plt.errorbar(T_eff_RW,L_RW, xerr = del_T_RW ,yerr= del_L_RW, ecolor='cyan')
# plt.errorbar(T_eff_KN,L_KN, xerr = del_T_KN ,yerr= del_L_KN, ecolor='linen')

#####Labels
plt.xlabel('Log T_eff (K)' ,color = 'w')
plt.ylabel('Log L (Solar Luminosity)',color = 'w')
plt.tick_params(axis = 'x' ,colors = 'w')
plt.tick_params(axis = 'y' ,colors = 'w')
axes.set_facecolor("Black")
fig.set_facecolor('k')
plt.title('Cep evolution ',color = 'white')
# plt.legend(loc = 'upper left')

# plt.xlim(4,3.6)
# plt.ylim(3.5,3.75)

# plt.plot(temp_8_25M[min_8_25left_RW],Lum_8_25M[min_8_25left_RW],'o-' ,color ='w')
# plt.plot(temp_8_25M[min_8_25right_RW],Lum_8_25M[min_8_25right_RW],'o-' ,color ='w')

# plt.plot(temp_8M[min_8left_RW],Lum_8M[min_8left_RW],'o-' ,color ='w')
# plt.plot(temp_8M[min_8right_RW],Lum_8M[min_8right_RW],'o-' ,color ='w')

# plt.plot(temp_10M[min_10left_RW],Lum_10M[min_10left_RW],'o-' ,color ='b')
# plt.plot(temp_10M[min_10right_RW],Lum_10M[min_10right_RW],'o-' ,color ='b')

# plt.plot(temp_10_25M[min_10_25left_RW],Lum_10_25M[min_10_25left_RW],'o-' ,color ='b')
# plt.plot(temp_10_25M[min_10_25right_RW],Lum_10_25M[min_10_25right_RW],'o-' ,color ='b')

# plt.plot(temp_9_75M[min_9_75left_RW],Lum_9_75M[min_9_75left_RW],'o-' ,color ='b')
# plt.plot(temp_9_75M[min_9_75right_RW],Lum_9_75M[min_9_75right_RW],'o-' ,color ='b')

# plt.plot(temp_5M[min_5left_CRW],Lum_5M[min_5left_CRW],'o-' ,color ='w')
# plt.plot(temp_5M[min_5right_CRW],Lum_5M[min_5right_CRW],'o-' ,color ='w')

# plt.plot(temp_5_25M[min_5_25left_CRW],Lum_5_25M[min_5_25left_CRW],'o-' ,color ='w')
# plt.plot(temp_5_25M[min_5_25right_CRW],Lum_5_25M[min_5_25right_CRW],'o-' ,color ='w')

# # plt.plot(temp_4_75M[min_4_75left_CRW],Lum_4_75M[min_4_75left_CRW],'o-' ,color ='w')        #Problem but fix by hand
# plt.plot(temp_4_75M[min_4_75right_CRW],Lum_4_75M[min_4_75right_CRW],'o-' ,color ='w')

####Isochrone

plt.plot(temp_3M[ISC_3M_for_8], Lum_3M[ISC_3M_for_8],'o-', color = 'w')
plt.plot(temp_4M[ISC_4M_for_8], Lum_4M[ISC_4M_for_8],'o-', color = 'w')
plt.plot(temp_5M[ISC_5M_for_8], Lum_5M[ISC_5M_for_8],'o-', color = 'w')
plt.plot(temp_6M[ISC_6M_for_8], Lum_6M[ISC_6M_for_8],'o-', color = 'w')
plt.plot(temp_7M[ISC_7M_for_8], Lum_7M[ISC_7M_for_8],'o-', color = 'w')
plt.plot(temp_8M[ISC_8M_for_8], Lum_8M[ISC_8M_for_8],'o-', color = 'w')
    Proofing
# for i in range(len(temp_4_75M)):
#     print(i, temp_4_75M[i])
# for i in range(len(temp_8M)):
#     print(i, temp_8M[i])
    Plotting
fig, axes = plt.subplots()
fig.set_figwidth(26)
fig.set_figheight(16)

# ##Tracks
# ##Tracks
plt.plot(temp_10M,Lum_10M,color ='orange')
plt.plot(temp_9M,Lum_9M ,color ='orange')
plt.plot(temp_8M,Lum_8M,color = 'orange')
plt.plot(temp_5M,Lum_5M ,color ='orange')

# plt.plot(temp_10_5M,Lum_10_5M,color ='w')         ## 5 Crossings
plt.plot(temp_9_5M,Lum_9_5M ,color ='y')
plt.plot(temp_8_5M,Lum_8_5M ,color ='y')
plt.plot(temp_7_5M,Lum_7_5M ,color ='w')


plt.plot(temp_5_25M,Lum_5_25M ,color ='g')
plt.plot(temp_8_25M,Lum_8_25M ,color ='g')
plt.plot(temp_9_25M,Lum_9_25M ,color ='g')
plt.plot(temp_10_25M,Lum_10_25M ,color ='g')

plt.plot(temp_4_75M,Lum_4_75M ,color ='teal')
plt.plot(temp_8_75M,Lum_8_75M ,color ='teal')
plt.plot(temp_9_75M,Lum_9_75M ,color ='teal')

#########Instability Strip
blue_left_edge = [3.91,3.76]
blue_right_edge = [2.4,4.5]
red_left_edge = [3.79,3.65]
red_right_edge = [2.4,4.5]

plt.plot(blue_left_edge,blue_right_edge, 'b')
plt.plot(red_left_edge,red_right_edge, 'r')
plt.gca().invert_xaxis()



#######Companion
plt.plot(T_eff_CSV, L_CSV, marker = 'X',color = 'pink')
plt.plot(T_eff_CRW, L_CRW, '^',color = 'cyan')
plt.plot(T_eff_CKN, L_CKN, 'P',color = 'linen')
# plt.errorbar(T_eff_CSV,L_CSV, xerr = del_T_CSV ,yerr= del_L_CSV, ecolor='pink')
plt.errorbar(T_eff_CRW,L_CRW, xerr = del_T_CRW ,yerr= del_L_CRW, ecolor='cyan')
# plt.errorbar(T_eff_CKN,L_CKN, xerr = del_T_CKN ,yerr= del_L_CKN, ecolor='linen')



#######Cepheid
plt.plot(T_eff_SV,L_SV, 'X',color = 'pink', label = 'SV Per')
plt.plot(T_eff_RW,L_RW, '^',color = 'cyan', label = 'RW Cam ')
plt.plot(T_eff_KN,L_KN, 'P',color = 'linen', label = 'KN Cen ')

# plt.errorbar(T_eff_SV,L_SV, xerr = del_T_SV ,yerr= del_L_SV, ecolor='pink')
plt.errorbar(T_eff_RW,L_RW, xerr = del_T_RW ,yerr= del_L_RW, ecolor='cyan')
# plt.errorbar(T_eff_KN,L_KN, xerr = del_T_KN ,yerr= del_L_KN, ecolor='linen')

#####Labels
plt.xlabel('Log T_eff (K)' ,color = 'w')
plt.ylabel('Log L (Solar Luminosity)',color = 'w')
plt.tick_params(axis = 'x' ,colors = 'w')
plt.tick_params(axis = 'y' ,colors = 'w')
axes.set_facecolor("Black")
fig.set_facecolor('k')
plt.title('Cep evolution ',color = 'white')
# plt.legend(loc = 'upper left')

# plt.xlim(4,3.6)
# plt.ylim(3.5,3.75)

plt.plot(temp_7_5M[min_7_5left_RW],Lum_7_5M[min_7_5left_RW],'o-' ,color ='r')
plt.plot(temp_7_5M[min_7_5right_RW],Lum_7_5M[min_7_5right_RW],'o-' ,color ='r')

plt.plot(temp_8_25M[min_8_25left_RW],Lum_8_25M[min_8_25left_RW],'o-' ,color ='w')
plt.plot(temp_8_25M[min_8_25right_RW],Lum_8_25M[min_8_25right_RW],'o-' ,color ='w')

plt.plot(temp_8M[min_8left_RW],Lum_8M[min_8left_RW],'o-' ,color ='w')
plt.plot(temp_8M[min_8right_RW],Lum_8M[min_8right_RW],'o-' ,color ='w')

plt.plot(temp_10M[min_10left_RW],Lum_10M[min_10left_RW],'o-' ,color ='b')
plt.plot(temp_10M[min_10right_RW],Lum_10M[min_10right_RW],'o-' ,color ='b')

plt.plot(temp_10_25M[min_10_25left_RW],Lum_10_25M[min_10_25left_RW],'o-' ,color ='b')
plt.plot(temp_10_25M[min_10_25right_RW],Lum_10_25M[min_10_25right_RW],'o-' ,color ='b')

plt.plot(temp_9_75M[min_9_75left_RW],Lum_9_75M[min_9_75left_RW],'o-' ,color ='b')
plt.plot(temp_9_75M[min_9_75right_RW],Lum_9_75M[min_9_75right_RW],'o-' ,color ='b')

plt.plot(temp_5M[min_5left_CRW],Lum_5M[min_5left_CRW],'o-' ,color ='w')
plt.plot(temp_5M[min_5right_CRW],Lum_5M[min_5right_CRW],'o-' ,color ='w')

plt.plot(temp_5_25M[min_5_25left_CRW],Lum_5_25M[min_5_25left_CRW],'o-' ,color ='w')
plt.plot(temp_5_25M[min_5_25right_CRW],Lum_5_25M[min_5_25right_CRW],'o-' ,color ='w')

# plt.plot(temp_4_75M[min_4_75left_CRW],Lum_4_75M[min_4_75left_CRW],'o-' ,color ='w')        #Problem but fix by hand
plt.plot(temp_4_75M[min_4_75right_CRW],Lum_4_75M[min_4_75right_CRW],'o-' ,color ='w')



###########Companionion needed age

plt.plot(temp_8M[NA_min_8left_CRW],Lum_8M[NA_min_8left_CRW],'o-' ,color ='m')
plt.plot(temp_8M[NA_min_8right_CRW],Lum_8M[NA_min_8right_CRW],'o-' ,color ='m')

fig, axes = plt.subplots()
fig.set_figwidth(30)
fig.set_figheight(18)

# ##Tracks

fontweight = 'bold'
plt.plot(Merger_temp_4_75_to_8M,Merger_Lum_4_75_to_8M,color ='teal', label = '4.75 to 8',linewidth = 7)
plt.plot(Merger_temp_4_25_to_8M,Merger_Lum_4_25_to_8M,color ='plum', label = '4.25 to 8',linewidth = 7)
plt.plot(Merger_temp_4_5_to_8M,Merger_Lum_4_5_to_8M,color ='dodgerblue', label = '4.5 to 8',linewidth = 7)
plt.plot(Merger_temp_4_to_8M,Merger_Lum_4_to_8M,color ='orange', label = '4 to 8',linewidth = 7)

# plt.plot(temp_8M,Lum_8M,color ='cyan')


#########Instability Strip
blue_left_edge = [3.91,3.76]
blue_right_edge = [2.4,4.5]
red_left_edge = [3.79,3.65]
red_right_edge = [2.4,4.5]

plt.plot(blue_left_edge,blue_right_edge, 'b')
plt.plot(red_left_edge,red_right_edge, 'r')
plt.gca().invert_xaxis()



#######Companion
# plt.plot(T_eff_CSV , L_CSV, marker = 'X',color = 'pink')
# plt.plot(T_eff_CRW, L_CRW, '^',color = 'cyan')
# plt.plot(T_eff_CKN, L_CKN, 'P',color = 'linen')
# plt.errorbar(T_eff_CSV,L_CSV, xerr = del_T_CSV ,yerr= del_L_CSV, ecolor='pink')
# plt.errorbar(T_eff_CRW,L_CRW, xerr = del_T_CRW ,yerr= del_L_CRW, ecolor='cyan')
# plt.errorbar(T_eff_CKN,L_CKN, xerr = del_T_CKN ,yerr= del_L_CKN, ecolor='linen')



#######Cepheid
# plt.plot(T_eff_SV,L_SV, 'X',color = 'pink', label = 'SV Per')
plt.plot(T_eff_RW,L_RW, '^',color = 'w', label = 'RW Cam ')
# plt.plot(T_eff_KN,L_KN, 'P',color = 'linen', label = 'KN Cen ')

# plt.errorbar(T_eff_SV,L_SV, xerr = del_T_SV ,yerr= del_L_SV, ecolor='pink')
plt.errorbar(T_eff_RW,L_RW, xerr = del_T_RW ,yerr= del_L_RW, ecolor='green', elinewidth=50)
# plt.errorbar(T_eff_KN,L_KN, xerr = del_T_KN ,yerr= del_L_KN, ecolor='linen')

#####Labels
plt.xlabel(r'Log $T_{eff}$ (K)' ,color = 'k', fontsize = '28')
plt.ylabel(r'Log L (L$_{\odot}$)',color = 'k' , fontsize = '28')
plt.tick_params(axis = 'x' ,colors = 'k')
plt.tick_params(axis = 'y' ,colors = 'k')
axes.set_facecolor("w")
fig.set_facecolor('w')
# plt.title('Merger Model-RW CAM ',color = 'k', fontsize = 25)
# plt.legend(loc = 'upper left')
plt.xticks(fontsize = 28);
plt.yticks(fontsize = 28);

# plt.xlim(4,3.6)
plt.ylim(2.2,4.4)

axes.text(0.10, 0.78, r'~8 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=28, transform=axes.transAxes, color = 'k')
axes.text(0.29, 0.55,r'Mass accretion stage; rate = 0.6 $\times$ 10$^{-6}$ $\frac{M_{\odot}}{\mathrm{yr}}$', horizontalalignment='center', verticalalignment='center', fontsize=28, transform=axes.transAxes, color = 'k')
axes.text(0.30, 0.21, '~75 Myr', horizontalalignment='center', verticalalignment='center', fontsize=28, transform=axes.transAxes, color = 'k')

axes.text(0.215, 0.070, r'4 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=28, transform=axes.transAxes, color = 'k')


axes.text(0.8145, 0.785,'RW' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=axes.transAxes, color = 'w',fontweight=fontweight)
axes.text(0.815, 0.76,'CAM' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=axes.transAxes, color = 'w',fontweight=fontweight)
Merger_ages_4_to_8M[-1]
Merger_ages_4_5_to_8M[-1]
Merger_ages_4_75_to_8M[-1]
Merger_ages_4_25_to_8M[-1]
History_file_3M = mr.MesaData('/home/sprasadh/general_3M/general/work/LOGS/history.data')
History_file_3_5M = mr.MesaData('/home/sprasadh/general_3_5M/general/work/LOGS/history.data')
History_file_4M = mr.MesaData('/home/sprasadh/general_4M/general/work/LOGS/history.data')
History_file_4_5M = mr.MesaData('/home/sprasadh/general_4_5M/general/work/LOGS/history.data')
History_file_5M = mr.MesaData('/home/sprasadh/general_5M/general/work/LOGS/history.data')
History_file_5_5M = mr.MesaData('/home/sprasadh/general_5_5M/general/work/LOGS/history.data')
History_file_6M = mr.MesaData('/home/sprasadh/general_6M/work/LOGS/history.data')
History_file_6_5M = mr.MesaData('/home/sprasadh/general_6_5M/general/work/LOGS/history.data')
History_file_7M = mr.MesaData('/home/sprasadh/general_7M_overshooting/general_7.5M/work/LOGS/history.data')
History_file_7_5M = mr.MesaData('/home/sprasadh/general_7_5M/general/work/LOGS/history.data')
History_file_8M = mr.MesaData('/home/sprasadh/general_8M/general_7.5M/work/LOGS/history.data')
History_file_8_5M = mr.MesaData('/home/sprasadh/general_8_5M/general/work/LOGS/history.data')
History_file_9M = mr.MesaData('/home/sprasadh/general_9M/general_7.5M/work/LOGS/history.data')
History_file_9_5M = mr.MesaData('/home/sprasadh/general_9_5M/general/work/LOGS/history.data')
History_file_10M = mr.MesaData('/home/sprasadh/general_10M/general/work/LOGS/history.data')
History_file_10_5M = mr.MesaData('/home/sprasadh/general_10_5M/general/work/LOGS/history.data')
History_file_11M = mr.MesaData('/home/sprasadh/general_11M/general_5M/general/work/LOGS/history.data')
History_file_11_5M = mr.MesaData('/home/sprasadh/general_11_5M/general/work/LOGS/history.data')
History_file_12M = mr.MesaData('/home/sprasadh/general_12M/general/work/LOGS/history.data')
History_file_12_5M = mr.MesaData('/home/sprasadh/general_12_5M/general/work/LOGS/history.data')
History_file_13M = mr.MesaData('/home/sprasadh/general_13M/general/work/LOGS/history.data')


History_file_3_25M = mr.MesaData('/home/sprasadh/general_3_25M/general/work/LOGS/history.data')
History_file_3_75M = mr.MesaData('/home/sprasadh/general_3_75M/general/work/LOGS/history.data')
History_file_4_25M = mr.MesaData('/home/sprasadh/general_4_25M/general/work/LOGS/history.data')
History_file_4_75M = mr.MesaData('/home/sprasadh/general_4_75M/general/work/LOGS/history.data')
History_file_5_25M = mr.MesaData('/home/sprasadh/general_5_25M/general/work/LOGS/history.data')
History_file_5_75M = mr.MesaData('/home/sprasadh/general_5_75M/general/work/LOGS/history.data')
History_file_6_25M = mr.MesaData('/home/sprasadh/general_6_25M/general/work/LOGS/history.data')
History_file_6_75M = mr.MesaData('/home/sprasadh/general_6_75M/general/work/LOGS/history.data')
History_file_7_25M = mr.MesaData('/home/sprasadh/general_7_25M/general/work/LOGS/history.data')
History_file_7_75M = mr.MesaData('/home/sprasadh/general_7_75M/general/work/LOGS/history.data')
History_file_8_25M = mr.MesaData('/home/sprasadh/general_8_25M/general/work/LOGS/history.data')
History_file_8_75M = mr.MesaData('/home/sprasadh/general_8_75M/general/work/LOGS/history.data')
History_file_9_25M = mr.MesaData('/home/sprasadh/general_9_25M/general/work/LOGS/history.data')
History_file_9_75M = mr.MesaData('/home/sprasadh/general_9_75M/general/work/LOGS/history.data')
History_file_10_25M = mr.MesaData('/home/sprasadh/general_10_25M/general/work/LOGS/history.data')
History_file_10_75M = mr.MesaData('/home/sprasadh/general_10_75M/general/work/LOGS/history.data')
History_file_11_25M = mr.MesaData('/home/sprasadh/general_11_25M/general/work/LOGS/history.data')
History_file_11_75M = mr.MesaData('/home/sprasadh/general_11_75M/general/work/LOGS/history.data')
History_file_12_25M = mr.MesaData('/home/sprasadh/general_12_25M/general/work/LOGS/history.data')
History_file_12_75M = mr.MesaData('/home/sprasadh/general_12_75M/general/work/LOGS/history.data')
    Merger

Merger_6_to_10M = mr.MesaData('/home/sprasadh/Merger_models/KN_Cen/6_to_10M/work/LOGS/history.data')
Merger_5_75_to_10M = mr.MesaData('/home/sprasadh/Merger_models/KN_Cen/5_75_to_10M/general/work/LOGS/history.data')
Merger_5_5_to_10M = mr.MesaData('/home/sprasadh/Merger_models/KN_Cen/5_5_to_10M/general/work/LOGS/history.data')
Merger_5_25_to_10M = mr.MesaData('/home/sprasadh/Merger_models/KN_Cen/5_25_to_10M/general/work/LOGS/history.data')
Merger_5_to_10M = mr.MesaData('/home/sprasadh/Merger_models/KN_Cen/5_to_10M/general/work/LOGS/history.data')
Merger_temp_6_to_10M = Merger_6_to_10M.data('Teff')
Merger_temp_6_to_10M = np.log10(Merger_temp_6_to_10M)
Merger_Lum_6_to_10M = Merger_6_to_10M.data('log_L')
Merger_ages_6_to_10M = Merger_6_to_10M.data('star_age')

Merger_temp_5_75_to_10M = Merger_5_75_to_10M.data('Teff')
Merger_temp_5_75_to_10M = np.log10(Merger_temp_5_75_to_10M)
Merger_Lum_5_75_to_10M = Merger_5_75_to_10M.data('log_L')
Merger_ages_5_75_to_10M = Merger_5_75_to_10M.data('star_age')

Merger_temp_5_5_to_10M = Merger_5_5_to_10M.data('Teff')
Merger_temp_5_5_to_10M = np.log10(Merger_temp_5_5_to_10M)
Merger_Lum_5_5_to_10M = Merger_5_5_to_10M.data('log_L')
Merger_ages_5_5_to_10M = Merger_5_5_to_10M.data('star_age')
Merger_temp_5_25_to_10M = Merger_5_25_to_10M.data('Teff')
Merger_temp_5_25_to_10M = np.log10(Merger_temp_5_25_to_10M)
Merger_Lum_5_25_to_10M = Merger_5_25_to_10M.data('log_L')
Merger_ages_5_25_to_10M = Merger_5_25_to_10M.data('star_age')

Merger_temp_5_to_10M = Merger_5_to_10M.data('Teff')
Merger_temp_5_to_10M = np.log10(Merger_temp_5_to_10M)
Merger_Lum_5_to_10M = Merger_5_to_10M.data('log_L')
Merger_ages_5_to_10M = Merger_5_to_10M.data('star_age')

    Normal tracks
temp_3M = History_file_3M.data('Teff')
temp_3M = np.log10(temp_3M)
Lum_3M = (History_file_3M.data('log_L'))
ages_3_5M = History_file_3_5M.data('star_age')
temp_3_5M = History_file_3_5M.data('Teff')
temp_3_5M = np.log10(temp_3_5M)
Lum_3_5M = History_file_3_5M.data('log_L')
temp_3_25M = History_file_3_25M.data('Teff')
temp_3_25M = np.log10(temp_3_25M)
Lum_3_25M = History_file_3_25M.data('log_L')
temp_3_75M = History_file_3_75M.data('Teff')
temp_3_75M = np.log10(temp_3_75M)
Lum_3_75M = History_file_3_75M.data('log_L')

ages_3_M = History_file_3M.data('star_age')
ages_3_25M = History_file_3_25M.data('star_age')
ages_3_5M = History_file_3_5M.data('star_age')
ages_3_75M = History_file_3_75M.data('star_age')

temp_4M = History_file_4M.data('Teff')
temp_4M = np.log10(temp_4M)
Lum_4M = (History_file_4M.data('log_L'))
ages_4_5M = History_file_4_5M.data('star_age')
temp_4_5M = History_file_4_5M.data('Teff')
temp_4_5M = np.log10(temp_4_5M)
Lum_4_5M = History_file_4_5M.data('log_L')
temp_4_25M = History_file_4_25M.data('Teff')
temp_4_25M = np.log10(temp_4_25M)
Lum_4_25M = History_file_4_25M.data('log_L')
temp_4_75M = History_file_4_75M.data('Teff')
temp_4_75M = np.log10(temp_4_75M)
Lum_4_75M = History_file_4_75M.data('log_L')

ages_4_M = History_file_4M.data('star_age')
ages_4_25M = History_file_4_25M.data('star_age')
ages_4_5M = History_file_4_5M.data('star_age')
ages_4_75M = History_file_4_75M.data('star_age')


ages_5M = History_file_5M.data('star_age')
temp_5M = History_file_5M.data('Teff')
temp_5M = np.log10(temp_5M)
Lum_5M = History_file_5M.data('log_L')
ages_5_5M = History_file_5_5M.data('star_age')
temp_5_5M = History_file_5_5M.data('Teff')
temp_5_5M = np.log10(temp_5_5M)
Lum_5_5M = History_file_5_5M.data('log_L')
temp_5_25M = History_file_5_25M.data('Teff')
temp_5_25M = np.log10(temp_5_25M)
Lum_5_25M = History_file_5_25M.data('log_L')
temp_5_75M = History_file_5_75M.data('Teff')
temp_5_75M = np.log10(temp_5_75M)
Lum_5_75M = History_file_5_75M.data('log_L')

ages_5_M = History_file_5M.data('star_age')
ages_5_25M = History_file_5_25M.data('star_age')
ages_5_5M = History_file_5_5M.data('star_age')
ages_5_75M = History_file_5_75M.data('star_age')

ages_6M = History_file_6M.data('star_age')
temp_6M = History_file_6M.data('Teff')
temp_6M = np.log10(temp_6M)
Lum_6M = (History_file_6M.data('log_L'))
ages_6_5M = History_file_6_5M.data('star_age')
temp_6_5M = History_file_6_5M.data('Teff')
temp_6_5M = np.log10(temp_6_5M)
Lum_6_5M = History_file_6_5M.data('log_L')
temp_6_25M = History_file_6_25M.data('Teff')
temp_6_25M = np.log10(temp_6_25M)
Lum_6_25M = History_file_6_25M.data('log_L')
temp_6_75M = History_file_6_75M.data('Teff')
temp_6_75M = np.log10(temp_6_75M)
Lum_6_75M = History_file_6_75M.data('log_L')

ages_6_M = History_file_6M.data('star_age')
ages_6_25M = History_file_6_25M.data('star_age')
ages_6_5M = History_file_6_5M.data('star_age')
ages_6_75M = History_file_6_75M.data('star_age')

ages_7M = History_file_7M.data('star_age')
temp_7M = History_file_7M.data('Teff')
temp_7M = np.log10(temp_7M)
Lum_7M = (History_file_7M.data('log_L'))
ages_7_5M = History_file_7_5M.data('star_age')
temp_7_5M = History_file_7_5M.data('Teff')
temp_7_5M = np.log10(temp_7_5M)
Lum_7_5M = History_file_7_5M.data('log_L')
temp_7_25M = History_file_7_25M.data('Teff')
temp_7_25M = np.log10(temp_7_25M)
Lum_7_25M = History_file_7_25M.data('log_L')
temp_7_75M = History_file_7_75M.data('Teff')
temp_7_75M = np.log10(temp_7_75M)
Lum_7_75M = History_file_7_75M.data('log_L')

ages_7_M = History_file_7M.data('star_age')
ages_7_25M = History_file_7_25M.data('star_age')
ages_7_5M = History_file_7_5M.data('star_age')
ages_7_75M = History_file_7_75M.data('star_age')

ages_8M = History_file_8M.data('star_age')
temp_8M = History_file_8M.data('Teff')
temp_8M = np.log10(temp_8M)
Lum_8M = (History_file_8M.data('log_L'))
ages_8_5M = History_file_8_5M.data('star_age')
temp_8_5M = History_file_8_5M.data('Teff')
temp_8_5M = np.log10(temp_8_5M)
Lum_8_5M = History_file_8_5M.data('log_L')
temp_8_25M = History_file_8_25M.data('Teff')
temp_8_25M = np.log10(temp_8_25M)
Lum_8_25M = History_file_8_25M.data('log_L')
temp_8_75M = History_file_8_75M.data('Teff')
temp_8_75M = np.log10(temp_8_75M)
Lum_8_75M = History_file_8_75M.data('log_L')

ages_8_M = History_file_8M.data('star_age')
ages_8_25M = History_file_8_25M.data('star_age')
ages_8_5M = History_file_8_5M.data('star_age')
ages_8_75M = History_file_8_75M.data('star_age')

ages_9M = History_file_9M.data('star_age')
temp_9M = History_file_9M.data('Teff')
temp_9M = np.log10(temp_9M)
Lum_9M = (History_file_9M.data('log_L'))
ages_9_5M = History_file_9_5M.data('star_age')
temp_9_5M = History_file_9_5M.data('Teff')
temp_9_5M = np.log10(temp_9_5M)
Lum_9_5M = History_file_9_5M.data('log_L')
temp_9_25M = History_file_9_25M.data('Teff')
temp_9_25M = np.log10(temp_9_25M)
Lum_9_25M = History_file_9_25M.data('log_L')
temp_9_75M = History_file_9_75M.data('Teff')
temp_9_75M = np.log10(temp_9_75M)
Lum_9_75M = History_file_9_75M.data('log_L')

ages_9_M = History_file_9M.data('star_age')
ages_9_25M = History_file_9_25M.data('star_age')
ages_9_5M = History_file_9_5M.data('star_age')
ages_9_75M = History_file_9_75M.data('star_age')

ages_10M = History_file_10M.data('star_age')
temp_10M = History_file_10M.data('Teff')
temp_10M = np.log10(temp_10M)
Lum_10M = (History_file_10M.data('log_L'))
temp_10_5M = History_file_10_5M.data('Teff')
temp_10_5M = np.log10(temp_10_5M)
Lum_10_5M = History_file_10_5M.data('log_L')
temp_10_25M = History_file_10_25M.data('Teff')
temp_10_25M = np.log10(temp_10_25M)
Lum_10_25M = History_file_10_25M.data('log_L')
temp_10_75M = History_file_10_75M.data('Teff')
temp_10_75M = np.log10(temp_10_75M)
Lum_10_75M = History_file_10_75M.data('log_L')

ages_10_M = History_file_10M.data('star_age')
ages_10_25M = History_file_10_25M.data('star_age')
ages_10_5M = History_file_10_5M.data('star_age')
ages_10_75M = History_file_10_75M.data('star_age')

ages_11M = History_file_11M.data('star_age')
temp_11M = History_file_11M.data('Teff')
temp_11M = np.log10(temp_11M)
Lum_11M = (History_file_11M.data('log_L'))
ages_11_5M = History_file_11_5M.data('star_age')
temp_11_5M = History_file_11_5M.data('Teff')
temp_11_5M = np.log10(temp_11_5M)
Lum_11_5M = History_file_11_5M.data('log_L')
temp_11_25M = History_file_11_25M.data('Teff')
temp_11_25M = np.log10(temp_11_25M)
Lum_11_25M = History_file_11_25M.data('log_L')
temp_11_75M = History_file_11_75M.data('Teff')
temp_11_75M = np.log10(temp_11_75M)
Lum_11_75M = History_file_11_75M.data('log_L')

ages_11_M = History_file_11M.data('star_age')
ages_11_25M = History_file_11_25M.data('star_age')
ages_11_5M = History_file_11_5M.data('star_age')
ages_11_75M = History_file_11_75M.data('star_age')

ages_12M = History_file_12M.data('star_age')
temp_12M = History_file_12M.data('Teff')
temp_12M = np.log10(temp_12M)
Lum_12M = (History_file_12M.data('log_L'))
ages_12_5M = History_file_12_5M.data('star_age')
temp_12_5M = History_file_12_5M.data('Teff')
temp_12_5M = np.log10(temp_12_5M)
Lum_12_5M = History_file_12_5M.data('log_L')
temp_12_25M = History_file_12_25M.data('Teff')
temp_12_25M = np.log10(temp_12_25M)
Lum_12_25M = History_file_12_25M.data('log_L')
temp_12_75M = History_file_12_75M.data('Teff')
temp_12_75M = np.log10(temp_12_75M)
Lum_12_75M = History_file_12_75M.data('log_L')

ages_12_M = History_file_12M.data('star_age')
ages_12_25M = History_file_12_25M.data('star_age')
ages_12_5M = History_file_12_5M.data('star_age')
ages_12_75M = History_file_12_75M.data('star_age')

ages_13M = History_file_13M.data('star_age')
temp_13M = History_file_13M.data('Teff')
temp_13M = np.log10(temp_13M)
Lum_13M = (History_file_13M.data('log_L'))

ages_13_M = History_file_13M.data('star_age')

P_KN = 34.029641
P_SV = 11.129318
P_RW = 16.414812

B_V_KN = 1.58
B_V_RW = 1.35
B_V_SV = 1.04

del_B_V = 0.02
    Companion temperature
B_V_CKN = -0.14
B_V_CRW = -0.08
B_V_CSV = -0.09

T_eff_CSV = 4.10
T_eff_CRW = 4.09
T_eff_CKN = 4.16


del_T_CSV = 0.005*T_eff_CSV
del_T_CRW = 0.005*T_eff_CRW
del_T_CKN = 0.005*T_eff_CKN
fie_SV = 0.716+ (0.225*B_V_SV)
fie_RW = 0.716+ (0.225*B_V_RW)
fie_KN = 0.716+ (0.225*B_V_KN)
del_fie_SV =  0.015+ (B_V_SV*0.017) + del_B_V*(0.225)
del_fie_RW =  0.015+ (B_V_RW*0.017) + del_B_V*(0.225)
del_fie_KN =  0.015+ (B_V_KN*0.017) + del_B_V*(0.225)
T_eff_SV = np.log10(5040/fie_SV)
T_eff_RW = np.log10(5040/fie_RW)
T_eff_KN = np.log10(5040/fie_KN)
del_T_SV_1= (del_fie_SV/fie_SV**2)
del_T_RW_1 = (del_fie_RW/fie_RW**2)
del_T_KN_1 = (del_fie_KN/fie_KN**2)
del_T_SV= (del_fie_SV/fie_SV**2)/T_eff_SV
del_T_RW = (del_fie_RW/fie_RW**2)/T_eff_RW
del_T_KN = (del_fie_KN/fie_KN**2)/T_eff_KN
a = -2.715
b = -4.153
del_beta = 0.060

P_SV = 11.1
P_RW = 16.2
P_KN = 34.4
M_v_SV = a*(np.log10(P_SV)-(np.log10(10))) + b
M_v_RW = a*(np.log10(P_RW)-(np.log10(10))) + b
M_v_KN = a*(np.log10(P_KN)-(np.log10(10))) + b
BC_SV = -0.161
BC_RW = -0.232
BC_KN = -0.161
del_P = 0.0001
M_bol_SV = M_v_SV + BC_SV
M_bol_RW = M_v_RW + BC_RW
M_bol_KN = M_v_KN + BC_KN
L_SV = (4.8-M_bol_SV)/2.5
L_RW = (4.8-M_bol_RW)/2.5
L_KN = (4.8-M_bol_KN)/2.5
del_Mv_SV = a*(del_P/P_SV) + del_beta
del_Mv_RW = a*(del_P/P_RW) + del_beta
del_Mv_KN = a*(del_P/P_KN) + del_beta

del_L_SV = (-M_bol_SV*del_Mv_SV)/2.5
del_L_RW = (-M_bol_RW*del_Mv_RW)/2.5
del_L_KN = (-M_bol_KN*del_Mv_KN)/2.5
    Companion Luminosity
L_CSV = 2.99
L_CRW = 3.11
L_CKN = 3.43
del_L_CSV = 0.02*L_CSV 
del_L_CRW = 0.02*L_CRW
del_L_CKN = 0.02*L_CKN
fig, axes = plt.subplots()
fig.set_figwidth(26)
fig.set_figheight(16)

# ##Tracks
# ##Tracks
plt.plot(temp_13M,Lum_13M,color ='orange' , label = 'N Mass')
plt.plot(temp_12M,Lum_12M,color ='orange')
plt.plot(temp_11M,Lum_11M,color ='orange')
plt.plot(temp_10M,Lum_10M,color ='orange')

plt.plot(temp_6M,Lum_6M ,color ='orange')


plt.plot(temp_12_5M,Lum_12_5M,color ='y', label = 'N.5 Mass')
# plt.plot(temp_11_5M,Lum_11_5M,color ='w')         ####Unable to complete 2nd crossing
# plt.plot(temp_10_5M,Lum_10_5M,color ='w')         ## 5 Crossings
plt.plot(temp_6_5M,Lum_6_5M ,color ='y')




plt.plot(temp_6_25M,Lum_6_25M ,color ='g')
plt.plot(temp_10_25M,Lum_10_25M ,color ='g')
plt.plot(temp_11_25M,Lum_11_25M ,color ='g')
# plt.plot(temp_12_25M,Lum_12_25M ,color ='g')     ## X and y array length dont match


plt.plot(temp_5_75M,Lum_5_75M ,color ='teal')
plt.plot(temp_10_75M,Lum_10_75M ,color ='teal')
plt.plot(temp_11_75M,Lum_11_75M ,color ='teal')
# plt.plot(temp_12_75M,Lum_12_75M ,color ='teal')   ## X and y array length dont match



#########Instability Strip
blue_left_edge = [3.91,3.76]
blue_right_edge = [2.4,4.5]
red_left_edge = [3.79,3.65]
red_right_edge = [2.4,4.5]

plt.plot(blue_left_edge,blue_right_edge, 'b')
plt.plot(red_left_edge,red_right_edge, 'r')
plt.gca().invert_xaxis()



#######Companion
plt.plot(T_eff_CSV, L_CSV, marker = 'X',color = 'pink')
plt.plot(T_eff_CRW, L_CRW, '^',color = 'cyan')
plt.plot(T_eff_CKN, L_CKN, 'P',color = 'linen')
# plt.errorbar(T_eff_CSV,L_CSV, xerr = del_T_CSV ,yerr= del_L_CSV, ecolor='pink')
# plt.errorbar(T_eff_CRW,L_CRW, xerr = del_T_CRW ,yerr= del_L_CRW, ecolor='cyan')
plt.errorbar(T_eff_CKN,L_CKN, xerr = del_T_CKN ,yerr= del_L_CKN, ecolor='linen')



#######Cepheid
plt.plot(T_eff_SV,L_SV, 'X',color = 'pink', label = 'SV Per')
plt.plot(T_eff_RW,L_RW, '^',color = 'cyan', label = 'RW Cam ')
plt.plot(T_eff_KN,L_KN, 'P',color = 'linen', label = 'KN Cen ')

# plt.errorbar(T_eff_SV,L_SV, xerr = del_T_SV ,yerr= del_L_SV, ecolor='pink')
# plt.errorbar(T_eff_RW,L_RW, xerr = del_T_RW ,yerr= del_L_RW, ecolor='cyan')
plt.errorbar(T_eff_KN,L_KN, xerr = del_T_KN ,yerr= del_L_KN, ecolor='linen')

#####Labels
plt.xlabel('Log T_eff (K)' ,color = 'w')
plt.ylabel('Log L (Solar Luminosity)',color = 'w')
plt.tick_params(axis = 'x' ,colors = 'w')
plt.tick_params(axis = 'y' ,colors = 'w')
axes.set_facecolor("Black")
fig.set_facecolor('k')
plt.title('Cep evolution ',color = 'white')
plt.legend(loc = 'upper left')

# plt.xlim(4,3.6)
# plt.ylim(3.5,3.75)
    Age - Companion
min_5_75left_CKN = np.argmin(np.abs(temp_5_75M - (T_eff_CKN + del_T_CKN))) 
Age_5_75left_CKN = ages_5_75M[min_5_75left_CKN]

min_5_75right_CKN = np.argmin(np.abs(temp_5_75M - (T_eff_CKN - del_T_CKN))) 
Age_5_75right_CKN = ages_5_75M[min_5_75right_CKN]

print(Age_5_75left_CKN)  
print(Age_5_75right_CKN)
min_6left_CKN = np.argmin(np.abs(temp_6M - (T_eff_CKN + del_T_CKN))) 
Age_6left_CKN = ages_6M[min_6left_CKN]

min_6right_CKN = np.argmin(np.abs(temp_6M - (T_eff_CKN - del_T_CKN))) 
Age_6right_CKN = ages_6M[min_6right_CKN]

print(Age_6left_CKN)
print(Age_6right_CKN)
min_6_25left_CKN = np.argmin(np.abs(temp_5_25M - (T_eff_CKN + del_T_CKN))) 
Age_6_25left_CKN = ages_6_25M[min_6_25left_CKN]

min_6_25right_CKN = np.argmin(np.abs(temp_6_25M - (T_eff_CKN - del_T_CKN))) 
Age_6_25right_CKN = ages_6_25M[min_6_25right_CKN]

print(Age_6_25left_CKN)
print(Age_6_25right_CKN)
    Needed Age for Companion
    
NA_min_9_75left_CKN = np.argmin(np.abs(temp_9_75M - (T_eff_CKN + del_T_CKN))) 
NA_Age_9_75left_CKN = ages_9_75M[NA_min_9_75left_CKN]

NA_min_9_75right_CKN = np.argmin(np.abs(temp_9_75M - (T_eff_CKN - del_T_CKN))) 
NA_Age_9_75right_CKN = ages_9_75M[NA_min_9_75right_CKN]

print(NA_Age_9_75left_CKN)  
print(NA_Age_9_75right_CKN)
    Age- Cepheid
Blue_loop_9_25_KN = int(len(temp_9_25M)*(0.6))

min_9_25left_KN = Blue_loop_9_25_KN + np.argmin(np.abs(temp_9_25M[Blue_loop_9_25_KN:] - (T_eff_KN + del_T_KN))) 
Age_9_25left_KN = ages_9_25M[min_9_25left_KN]

min_9_25right_KN = Blue_loop_9_25_KN +np.argmin(np.abs(temp_9_25M[Blue_loop_9_25_KN:] - (T_eff_KN - del_T_KN))) 
Age_9_25right_KN = ages_9_25M[min_9_25right_KN]

print(Age_9_25left_KN)
print(Age_9_25right_KN)
Blue_loop_10_KN = int(len(temp_10M)*(0.6))

min_10left_KN = Blue_loop_10_KN + np.argmin(np.abs(temp_10M[Blue_loop_10_KN:] - (T_eff_KN + del_T_KN))) 
Age_10left_KN = ages_10M[min_10left_KN]

min_10right_KN = Blue_loop_10_KN +np.argmin(np.abs(temp_10M[Blue_loop_10_KN:] - (T_eff_KN - del_T_KN))) 
Age_10right_KN = ages_10M[min_10right_KN]

print(Age_10left_KN)
print(Age_10right_KN)
Blue_loop_10_25_KN = int(len(temp_10_25M)*(0.6))

min_10_25left_KN = Blue_loop_10_25_KN + np.argmin(np.abs(temp_10_25M[Blue_loop_10_25_KN:] - (T_eff_KN + del_T_KN))) 
Age_10_25left_KN = ages_10_25M[min_10_25left_KN]

min_10_25right_KN = Blue_loop_10_25_KN +np.argmin(np.abs(temp_10_25M[Blue_loop_10_25_KN:] - (T_eff_KN - del_T_KN))) 
Age_10_25right_KN = ages_10_25M[min_10_25right_KN]

print(Age_10_25left_KN)
print(Age_10_25right_KN)
Blue_loop_10_75_KN = int(len(temp_10_75M)*(0.6))

min_10_75left_KN = Blue_loop_10_75_KN + np.argmin(np.abs(temp_10_75M[Blue_loop_10_75_KN:] - (T_eff_KN + del_T_KN))) 
Age_10_75left_KN = ages_10_75M[min_10_75left_KN]

min_10_75right_KN = Blue_loop_10_75_KN +np.argmin(np.abs(temp_10_75M[Blue_loop_10_75_KN:] - (T_eff_KN - del_T_KN))) 
Age_10_75right_KN = ages_10_75M[min_10_75right_KN]

print(Age_10_75left_KN)
print(Age_10_75right_KN)
First_crossing_13M_KN = int(len(temp_13M)*(0.5))

min_13left_KN = np.argmin(np.abs(temp_13M[0:First_crossing_13M_KN] - (T_eff_KN + del_T_KN))) 
Age_13left_KN = ages_13M[min_13left_KN]

min_13right_KN = np.argmin(np.abs(temp_13M[0:First_crossing_13M_KN] - (T_eff_KN - del_T_KN))) 
Age_13right_KN = ages_13M[min_13right_KN]

print(Age_13left_KN)
print(Age_13right_KN)
First_crossing_12_75M_KN = int(len(temp_12_75M)*(0.5))

min_12_75left_KN = np.argmin(np.abs(temp_12_75M[0:First_crossing_12_75M_KN] - (T_eff_KN + del_T_KN))) 
Age_12_75left_KN = ages_12_75M[min_12_75left_KN]

min_12_75right_KN = np.argmin(np.abs(temp_12_75M[0:First_crossing_12_75M_KN] - (T_eff_KN - del_T_KN))) 
Age_12_75right_KN = ages_12_75M[min_12_75right_KN]

print(Age_12_75left_KN)
print(Age_12_75right_KN)
First_crossing_12_5M_KN = int(len(temp_12_5M)*(0.5))

min_12_5left_KN = np.argmin(np.abs(temp_12_5M[0:First_crossing_12_5M_KN] - (T_eff_KN + del_T_KN))) 
Age_12_5left_KN = ages_12_5M[min_12_5left_KN]

min_12_5right_KN = np.argmin(np.abs(temp_12_5M[0:First_crossing_12_5M_KN] - (T_eff_KN - del_T_KN))) 
Age_12_5right_KN = ages_12_5M[min_12_5right_KN]

print(Age_12_5left_KN)
print(Age_12_5right_KN)
Age_9_25left_KN
    Just because I dont want to write again.
LEt age 6.75 = age 7
Age_10left_KN = Age_9_25left_KN
    Isochrone
ISC_3M_for_10 = np.argmin(np.abs(ages_3_M - Age_10left_KN))
ISC_4M_for_10 = np.argmin(np.abs(ages_4_M - Age_10left_KN))
ISC_5M_for_10 = np.argmin(np.abs(ages_5_M - Age_10left_KN))
ISC_6M_for_10 = np.argmin(np.abs(ages_6_M - Age_10left_KN))
ISC_7M_for_10 = np.argmin(np.abs(ages_7_M - Age_10left_KN))
ISC_8M_for_10 = np.argmin(np.abs(ages_8_M - Age_10left_KN))
ISC_9M_for_10 = np.argmin(np.abs(ages_9_M - Age_10left_KN))
ISC_10M_for_10 = np.argmin(np.abs(ages_10_M - Age_10left_KN))

ISC_3_25M_for_10 = np.argmin(np.abs(ages_3_25M - Age_10left_KN))
ISC_4_25M_for_10 = np.argmin(np.abs(ages_4_25M - Age_10left_KN))
ISC_5_25M_for_10 = np.argmin(np.abs(ages_5_25M - Age_10left_KN))
ISC_6_25M_for_10 = np.argmin(np.abs(ages_6_25M - Age_10left_KN))
ISC_7_25M_for_10 = np.argmin(np.abs(ages_7_25M - Age_10left_KN))
ISC_8_25M_for_10 = np.argmin(np.abs(ages_8_25M - Age_10left_KN))
ISC_9_25M_for_10 = np.argmin(np.abs(ages_9_25M - Age_10left_KN))
ISC_10_25M_for_10 = np.argmin(np.abs(ages_10_25M - Age_10left_KN))

ISC_3_5M_for_10 = np.argmin(np.abs(ages_3_5M - Age_10left_KN))
ISC_4_5M_for_10 = np.argmin(np.abs(ages_4_5M - Age_10left_KN))
ISC_5_5M_for_10 = np.argmin(np.abs(ages_5_5M - Age_10left_KN))
ISC_6_5M_for_10 = np.argmin(np.abs(ages_6_5M - Age_10left_KN))
ISC_7_5M_for_10 = np.argmin(np.abs(ages_7_5M - Age_10left_KN))
ISC_8_5M_for_10 = np.argmin(np.abs(ages_8_5M - Age_10left_KN))
ISC_9_5M_for_10 = np.argmin(np.abs(ages_9_5M - Age_10left_KN))
ISC_10_5M_for_10 = np.argmin(np.abs(ages_10_5M - Age_10left_KN))

ISC_3_75M_for_10 = np.argmin(np.abs(ages_3_75M - Age_10left_KN))
ISC_4_75M_for_10 = np.argmin(np.abs(ages_4_75M - Age_10left_KN))
ISC_5_75M_for_10 = np.argmin(np.abs(ages_5_75M - Age_10left_KN))
ISC_6_75M_for_10 = np.argmin(np.abs(ages_6_75M - Age_10left_KN))
ISC_7_75M_for_10 = np.argmin(np.abs(ages_7_75M - Age_10left_KN))
ISC_8_75M_for_10 = np.argmin(np.abs(ages_8_75M - Age_10left_KN))
ISC_9_75M_for_10 = np.argmin(np.abs(ages_9_75M - Age_10left_KN))
ISC_10_75M_for_10 = np.argmin(np.abs(ages_10_75M - Age_10left_KN))


ages_9M[ISC_9M_for_10]
Age_10left_KN
    Plotting Isochrone
    
    KN CEN
    
ISC_KN = np.zeros([26,2])
ISC_KN[0,:] = temp_3M[ISC_3M_for_10],Lum_3M[ISC_3M_for_10]
ISC_KN[4,:] = temp_4M[ISC_4M_for_10],Lum_4M[ISC_4M_for_10]
ISC_KN[8,:] = temp_5M[ISC_5M_for_10],Lum_5M[ISC_5M_for_10]
ISC_KN[12,:] = temp_6M[ISC_6M_for_10],Lum_6M[ISC_6M_for_10]
ISC_KN[16,:] = temp_7M[ISC_7M_for_10],Lum_7M[ISC_7M_for_10]
ISC_KN[20,:] = temp_8M[ISC_8M_for_10],Lum_8M[ISC_8M_for_10]
ISC_KN[24,:] = temp_9M[ISC_9M_for_10], Lum_9M[ISC_9M_for_10]


ISC_KN[1,:] = temp_3_25M[ISC_3_25M_for_10], Lum_3_25M[ISC_3_25M_for_10]
ISC_KN[5,:] = temp_4_25M[ISC_4_25M_for_10], Lum_4_25M[ISC_4_25M_for_10]
ISC_KN[9,:] = temp_5_25M[ISC_5_25M_for_10], Lum_5_25M[ISC_5_25M_for_10]
ISC_KN[13,:] = temp_6_25M[ISC_6_25M_for_10], Lum_6_25M[ISC_6_25M_for_10]
ISC_KN[17,:] = temp_7_25M[ISC_7_25M_for_10], Lum_7_25M[ISC_7_25M_for_10]
ISC_KN[21,:] = temp_8_25M[ISC_8_25M_for_10], Lum_8_25M[ISC_8_25M_for_10]
ISC_KN[25,:] = temp_9_25M[ISC_9_25M_for_10], Lum_9_25M[ISC_9_25M_for_10]

ISC_KN[2,:] = temp_3_5M[ISC_3_5M_for_10], Lum_3_5M[ISC_3_5M_for_10]
ISC_KN[6,:] = temp_4_5M[ISC_4_5M_for_10], Lum_4_5M[ISC_4_5M_for_10]
ISC_KN[10,:] = temp_5_5M[ISC_5_5M_for_10], Lum_5_5M[ISC_5_5M_for_10]
ISC_KN[14,:] = temp_6_5M[ISC_6_5M_for_10], Lum_6_5M[ISC_6_5M_for_10]
ISC_KN[18,:] = temp_7_5M[ISC_7_5M_for_10], Lum_7_5M[ISC_7_5M_for_10]
ISC_KN[22,:] = temp_8_5M[ISC_8_5M_for_10], Lum_8_5M[ISC_8_5M_for_10]
# ISC_KN[26,:] = temp_9_5M[ISC_9_5M_for_10], Lum_9_5M[ISC_9_5M_for_10]

ISC_KN[3,:] = temp_3_75M[ISC_3_75M_for_10], Lum_3_75M[ISC_3_75M_for_10]
ISC_KN[7,:] = temp_4_75M[ISC_4_75M_for_10], Lum_4_75M[ISC_4_75M_for_10]
ISC_KN[11,:] = temp_5_75M[ISC_5_75M_for_10], Lum_5_75M[ISC_5_75M_for_10]
ISC_KN[15,:] = temp_6_75M[ISC_6_75M_for_10], Lum_6_75M[ISC_6_75M_for_10]
ISC_KN[19,:] = temp_7_75M[ISC_7_75M_for_10], Lum_7_75M[ISC_7_75M_for_10]
ISC_KN[23,:] = temp_8_75M[ISC_8_75M_for_10], Lum_8_75M[ISC_8_75M_for_10]
# ISC_KN[27,:] = temp_9_75M[ISC_9_75M_for_10], Lum_9_75M[ISC_9_75M_for_10]



    SV PER
    
Blue_loop_6_75M_SV = int(len(temp_6_75M)*(0.6))
min_6_75left_SV = Blue_loop_6_75M_SV + np.argmin(np.abs(temp_6_75M[Blue_loop_6_75M_SV:] - (T_eff_SV + del_T_SV))) 
Age_6_75left_SV = ages_6_75M[min_6_75left_SV]

min_6_75right_SV = Blue_loop_6_75M_SV + np.argmin(np.abs(temp_6_25M[Blue_loop_6_75M_SV:] - (T_eff_SV - del_T_SV))) 
Age_6_75right_SV = ages_6_75M[min_6_75right_SV]

print(Age_6_75left_SV)
print(Age_6_75right_SV)
Blue_loop_7_SV = int(len(temp_7M)*(0.6))
min_7left_SV = Blue_loop_7_SV + np.argmin(np.abs( temp_7M[Blue_loop_7_SV:]- (T_eff_SV + del_T_SV))) 
Age_7left_SV = ages_7M[min_7left_SV]

min_7right_SV = Blue_loop_7_SV + np.argmin(np.abs(temp_7M[Blue_loop_7_SV:] - (T_eff_SV - del_T_SV))) 
Age_7right_SV = ages_7M[min_7right_SV]

print(Age_7left_SV)
print(Age_7right_SV)
    Just because I dont want to write again.
LEt age 6.75 = age 7
Age_7left_SV = Age_6_75left_SV
ISC_3M_for_7 = np.argmin(np.abs(ages_3_M - Age_7left_SV))
ISC_4M_for_7 = np.argmin(np.abs(ages_4_M - Age_7left_SV))
ISC_5M_for_7 = np.argmin(np.abs(ages_5_M - Age_7left_SV))
ISC_6M_for_7 = np.argmin(np.abs(ages_6_M - Age_7left_SV))
ISC_7M_for_7 = np.argmin(np.abs(ages_7_M - Age_7left_SV))


ISC_3_25M_for_7 = np.argmin(np.abs(ages_3_25M - Age_7left_SV))
ISC_4_25M_for_7 = np.argmin(np.abs(ages_4_25M - Age_7left_SV))
ISC_5_25M_for_7 = np.argmin(np.abs(ages_5_25M - Age_7left_SV))
ISC_6_25M_for_7 = np.argmin(np.abs(ages_6_25M - Age_7left_SV))
ISC_7_25M_for_7 = np.argmin(np.abs(ages_7_25M - Age_7left_SV))


ISC_3_5M_for_7 = np.argmin(np.abs(ages_3_5M - Age_7left_SV))
ISC_4_5M_for_7 = np.argmin(np.abs(ages_4_5M - Age_7left_SV))
ISC_5_5M_for_7 = np.argmin(np.abs(ages_5_5M - Age_7left_SV))
ISC_6_5M_for_7 = np.argmin(np.abs(ages_6_5M - Age_7left_SV))
ISC_3_75M_for_7 = np.argmin(np.abs(ages_3_75M - Age_7left_SV))
ISC_4_75M_for_7 = np.argmin(np.abs(ages_4_75M - Age_7left_SV))
ISC_5_75M_for_7 = np.argmin(np.abs(ages_5_75M - Age_7left_SV))
ISC_6_75M_for_7 = np.argmin(np.abs(ages_6_75M - Age_7left_SV))

ISC_SV = np.zeros([16,2])

ISC_SV[0,:] = temp_3M[ISC_3M_for_7],Lum_3M[ISC_3M_for_7]
ISC_SV[4,:] = temp_4M[ISC_4M_for_7],Lum_4M[ISC_4M_for_7]
ISC_SV[8,:] = temp_5M[ISC_5M_for_7],Lum_5M[ISC_5M_for_7]
ISC_SV[12,:] = temp_6M[ISC_6M_for_7],Lum_6M[ISC_6M_for_7]
# ISC_SV[16,:] = temp_7M[ISC_7M_for_7],Lum_7M[ISC_7M_for_7]


ISC_SV[1,:] = temp_3_25M[ISC_3_25M_for_7], Lum_3_25M[ISC_3_25M_for_7]
ISC_SV[5,:] = temp_4_25M[ISC_4_25M_for_7], Lum_4_25M[ISC_4_25M_for_7]
ISC_SV[9,:] = temp_5_25M[ISC_5_25M_for_7], Lum_5_25M[ISC_5_25M_for_7]
ISC_SV[13,:] = temp_6_25M[ISC_6_25M_for_7], Lum_6_25M[ISC_6_25M_for_7]
# ISC_SV[17,:] = temp_7_25M[ISC_7_25M_for_7], Lum_7_25M[ISC_7_25M_for_7]

ISC_SV[2,:] = temp_3_5M[ISC_3_5M_for_7], Lum_3_5M[ISC_3_5M_for_7]
ISC_SV[6,:] = temp_4_5M[ISC_4_5M_for_7], Lum_4_5M[ISC_4_5M_for_7]
ISC_SV[10,:] = temp_5_5M[ISC_5_5M_for_7], Lum_5_5M[ISC_5_5M_for_7]
ISC_SV[14,:] = temp_6_5M[ISC_6_5M_for_7], Lum_6_5M[ISC_6_5M_for_7]

ISC_SV[3,:] = temp_3_75M[ISC_3_75M_for_7], Lum_3_75M[ISC_3_75M_for_7]
ISC_SV[7,:] = temp_4_75M[ISC_4_75M_for_7], Lum_4_75M[ISC_4_75M_for_7]
ISC_SV[11,:] = temp_5_75M[ISC_5_75M_for_7], Lum_5_75M[ISC_5_75M_for_7]
ISC_SV[15,:] = temp_6_75M[ISC_6_75M_for_7], Lum_6_75M[ISC_6_75M_for_7]
ISC_7_75M_for_10 = np.argmin(np.abs(ages_7_75M - Age_10left_KN))


    IsoChrone- RW CAM

Blue_loop_7_5_RW = int(len(temp_7_5M)*(0.6))
min_7_5left_RW = Blue_loop_7_5_RW + np.argmin(np.abs(temp_7_5M[Blue_loop_7_5_RW:] - (T_eff_RW + del_T_RW))) 
Age_7_5left_RW = ages_7_5M[min_7_5left_RW]

min_7_5right_RW = Blue_loop_7_5_RW + np.argmin(np.abs(temp_7_5M[Blue_loop_7_5_RW:] - (T_eff_RW - del_T_RW))) 
Age_7_5right_RW = ages_7_5M[min_7_5right_RW]

print(Age_7_5left_RW)
print(Age_7_5right_RW)
Blue_loop_7_75_RW = int(len(temp_7_75M)*(0.6))
min_7_75left_RW = Blue_loop_7_75_RW + np.argmin(np.abs(temp_7_75M[Blue_loop_7_75_RW:] - (T_eff_RW + del_T_RW))) 
Age_7_75left_RW = ages_7_75M[min_7_75left_RW]

min_7_75right_RW = Blue_loop_7_75_RW + np.argmin(np.abs(temp_7_75M[Blue_loop_7_75_RW:] - (T_eff_RW - del_T_RW))) 
Age_7_75right_RW = ages_7_75M[min_7_75right_RW]

print(Age_7_75left_RW)
print(Age_7_75right_RW)
# Blue_loop_8_RW = int(len(temp_8M)*(0.6))

# min_8left_RW = Blue_loop_8_RW + np.argmin(np.abs(temp_8M[Blue_loop_8_RW:] - (T_eff_RW + del_T_RW))) 
# Age_8left_RW = ages_8M[min_8left_RW]

# min_8right_RW = Blue_loop_8_RW +np.argmin(np.abs(temp_8M[Blue_loop_8_RW:] - (T_eff_RW - del_T_RW))) 
# Age_8right_RW = ages_8M[min_8right_RW]

# print(Age_8left_RW)
# print(Age_8right_RW)
Just because I dont want to write again.
LEt age 7.5 = age 8
Age_8left_RW = Age_7_75left_RW
ISC_3M_for_8 = np.argmin(np.abs(ages_3_M - Age_8left_RW))
ISC_4M_for_8 = np.argmin(np.abs(ages_4_M - Age_8left_RW))
ISC_5M_for_8 = np.argmin(np.abs(ages_5_M - Age_8left_RW))
ISC_6M_for_8 = np.argmin(np.abs(ages_6_M - Age_8left_RW))
ISC_7M_for_8 = np.argmin(np.abs(ages_7_M - Age_8left_RW))


ISC_3_25M_for_8 = np.argmin(np.abs(ages_3_25M - Age_8left_RW))
ISC_4_25M_for_8 = np.argmin(np.abs(ages_4_25M - Age_8left_RW))
ISC_5_25M_for_8 = np.argmin(np.abs(ages_5_25M - Age_8left_RW))
ISC_6_25M_for_8 = np.argmin(np.abs(ages_6_25M - Age_8left_RW))
ISC_7_25M_for_8 = np.argmin(np.abs(ages_7_25M - Age_8left_RW))


ISC_3_5M_for_8 = np.argmin(np.abs(ages_3_5M - Age_8left_RW))
ISC_4_5M_for_8 = np.argmin(np.abs(ages_4_5M - Age_8left_RW))
ISC_5_5M_for_8 = np.argmin(np.abs(ages_5_5M - Age_8left_RW))
ISC_6_5M_for_8 = np.argmin(np.abs(ages_6_5M - Age_8left_RW))
ISC_7_5M_for_8 = np.argmin(np.abs(ages_7_5M - Age_8left_RW))
ISC_3_75M_for_8 = np.argmin(np.abs(ages_3_75M - Age_8left_RW))
ISC_4_75M_for_8 = np.argmin(np.abs(ages_4_75M - Age_8left_RW))
ISC_5_75M_for_8 = np.argmin(np.abs(ages_5_75M - Age_8left_RW))
ISC_6_75M_for_8 = np.argmin(np.abs(ages_6_75M - Age_8left_RW))
ISC_7_75M_for_8 = np.argmin(np.abs(ages_7_75M - Age_8left_RW))
ISC_RW = np.zeros([20,2])

ISC_RW[0,:] = temp_3M[ISC_3M_for_8],Lum_3M[ISC_3M_for_8]
ISC_RW[4,:] = temp_4M[ISC_4M_for_8],Lum_4M[ISC_4M_for_8]
ISC_RW[8,:] = temp_5M[ISC_5M_for_8],Lum_5M[ISC_5M_for_8]
ISC_RW[12,:] = temp_6M[ISC_6M_for_8],Lum_6M[ISC_6M_for_8]
ISC_RW[16,:] = temp_7M[ISC_7M_for_8],Lum_7M[ISC_7M_for_8]


ISC_RW[1,:] = temp_3_25M[ISC_3_25M_for_8], Lum_3_25M[ISC_3_25M_for_8]
ISC_RW[5,:] = temp_4_25M[ISC_4_25M_for_8], Lum_4_25M[ISC_4_25M_for_8]
ISC_RW[9,:] = temp_5_25M[ISC_5_25M_for_8], Lum_5_25M[ISC_5_25M_for_8]
ISC_RW[13,:] = temp_6_25M[ISC_6_25M_for_8], Lum_6_25M[ISC_6_25M_for_8]
ISC_RW[17,:] = temp_7_25M[ISC_7_25M_for_8], Lum_7_25M[ISC_7_25M_for_8]

ISC_RW[2,:] = temp_3_5M[ISC_3_5M_for_8], Lum_3_5M[ISC_3_5M_for_8]
ISC_RW[6,:] = temp_4_5M[ISC_4_5M_for_8], Lum_4_5M[ISC_4_5M_for_8]
ISC_RW[10,:] = temp_5_5M[ISC_5_5M_for_8], Lum_5_5M[ISC_5_5M_for_8]
ISC_RW[14,:] = temp_6_5M[ISC_6_5M_for_8], Lum_6_5M[ISC_6_5M_for_8]
ISC_RW[18,:] = temp_7_5M[ISC_7_5M_for_8], Lum_7_5M[ISC_7_5M_for_8]

ISC_RW[3,:] = temp_3_75M[ISC_3_75M_for_8], Lum_3_75M[ISC_3_75M_for_8]
ISC_RW[7,:] = temp_4_75M[ISC_4_75M_for_8], Lum_4_75M[ISC_4_75M_for_8]
ISC_RW[11,:] = temp_5_75M[ISC_5_75M_for_8], Lum_5_75M[ISC_5_75M_for_8]
ISC_RW[15,:] = temp_6_75M[ISC_6_75M_for_8], Lum_6_75M[ISC_6_75M_for_8]
ISC_RW[19,:] = temp_7_75M[ISC_7_75M_for_8], Lum_7_75M[ISC_7_75M_for_8]

np.savetxt('/home/sprasadh/Saved_text_files/ISC_SV_REG', ISC_SV)
np.savetxt('/home/sprasadh/Saved_text_files/ISC_RW_REG', ISC_RW)
np.savetxt('/home/sprasadh/Saved_text_files/ISC_KN_REG', ISC_KN)
fig, ax = plt.subplots(1, figsize=(26, 16))

fontweight='bold'
#########Instability Strip
blue_left_edge = [3.91, 3.76]
blue_right_edge = [2.4, 4.5]
red_left_edge = [3.79, 3.65]
red_right_edge = [2.4, 4.5]

ax.plot(blue_left_edge, blue_right_edge, 'b')
ax.plot(red_left_edge, red_right_edge, 'r')
ax.invert_xaxis()

#######Companion
ax.plot(T_eff_CSV, L_CSV, marker='X', color='magenta', markersize=22)
ax.plot(T_eff_CRW, L_CRW, '^', color='green', markersize=22)
ax.plot(T_eff_CKN, L_CKN, 'P', color='darkslategrey', markersize=22)

#######Cepheid
ax.plot(T_eff_SV, L_SV, 'X', color='magenta', label='SV Per')
ax.plot(T_eff_RW, L_RW, '^', color='green', label='RW Cam')
ax.plot(T_eff_KN, L_KN, 'P', color='darkslategrey', label='KN Cen')

ax.errorbar(T_eff_SV, L_SV, xerr=del_T_SV, yerr=del_L_SV, ecolor='magenta', elinewidth=45)
ax.errorbar(T_eff_RW, L_RW, xerr=del_T_RW, yerr=del_L_RW, ecolor='green', elinewidth=45)
ax.errorbar(T_eff_KN, L_KN, xerr=del_T_KN, yerr=del_L_KN, ecolor='darkslategrey', elinewidth=45)

#####Labels
plt.xlabel(r'Log $T_{eff}$ (K)' ,color = 'k', fontsize = '28')
plt.ylabel(r'Log L (L$_{\odot}$)',color = 'k' , fontsize = '28')
ax.tick_params(axis='x', colors='k')
ax.tick_params(axis='y', colors='k')
ax.set_facecolor("w")
fig.set_facecolor('w')

plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

ax.plot(ISC_SV[:, 0], ISC_SV[:, 1], color='magenta',linestyle='--')
ax.plot(ISC_RW[:, 0], ISC_RW[:, 1], color='green',linestyle='--')

ax.text(0.86, 0.87, 'KN', horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.86, 0.845, 'CEN', horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.832, 0.74,'RW' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.832, 0.72,'CAM' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.79, 0.68,'SV' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.79, 0.66,'PER' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)

ax.text(0.09, 0.77, '28 Myr', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'darkslategrey')
ax.text(0.09, 0.69,'38 Myr' , horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'g')
ax.text(0.15, 0.565,'52 Myr' , horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'magenta')


ax.text(0.26, 0.581, '56 Myr', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'darkslategrey')
ax.text(0.35, 0.464, '84 Myr', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'g')
ax.text(0.34, 0.422, '91 Myr', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'magenta')

ax.text(0.218, 0.607, '(B6.0 \u2164)', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'darkslategrey')
ax.text(0.31, 0.492, '(B8.2 \u2162)', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'g')
ax.text(0.30, 0.392, '(B8 \u2162)', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'magenta')

# ax.text(0.26, 0.9, 'Isochrone for Cepheid', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'k')

# ax.set_xlim(4.32,3.6)
# plt.plot(temp_6_75M,Lum_6_75M,color ='k')
ax.plot(ISC_KN[:, 0], ISC_KN[:, 1], color='darkslategrey',linestyle='--')

    Proofing
fig, axes = plt.subplots()
fig.set_figwidth(26)
fig.set_figheight(16)

# ##Tracks

plt.plot(Merger_temp_5_75_to_10M,Merger_Lum_5_75_to_10M,color ='teal', label = '5.75 to 8')
plt.plot(Merger_temp_6_to_10M,Merger_Lum_6_to_10M,'o-'  , color ='orange', label = '6 ')
plt.plot(Merger_temp_5_25_to_10M,Merger_Lum_5_25_to_10M ,color ='g', label = '5.25 to 8')
plt.plot(Merger_temp_5_to_10M,Merger_Lum_5_to_10M , color ='purple', label = '5 to 8', )

# plt.plot(temp_10M,Lum_10M,color ='beige')


#########Instability Strip
blue_left_edge = [3.91,3.76]
blue_right_edge = [2.4,4.5]
red_left_edge = [3.79,3.65]
red_right_edge = [2.4,4.5]

plt.plot(blue_left_edge,blue_right_edge, 'b')
plt.plot(red_left_edge,red_right_edge, 'r')
plt.gca().invert_xaxis()



#######Companion
# plt.plot(T_eff_CSV, L_CSV, marker = 'X',color = 'pink')
# plt.plot(T_eff_CRW, L_CRW, '^',color = 'cyan')
plt.plot(T_eff_CKN, L_CKN, 'P',color = 'linen')
# plt.errorbar(T_eff_CSV,L_CSV, xerr = del_T_CSV ,yerr= del_L_CSV, ecolor='pink')
# plt.errorbar(T_eff_CRW,L_CRW, xerr = del_T_CRW ,yerr= del_L_CRW, ecolor='cyan')
plt.errorbar(T_eff_CKN,L_CKN, xerr = del_T_CKN ,yerr= del_L_CKN, ecolor='linen')



#######Cepheid
# plt.plot(T_eff_SV,L_SV, 'X',color = 'pink', label = 'SV Per')
# plt.plot(T_eff_RW,L_RW, '^',color = 'cyan', label = 'RW Cam ')
plt.plot(T_eff_KN,L_KN, 'P',color = 'linen', label = 'KN Cen ')

# plt.errorbar(T_eff_SV,L_SV, xerr = del_T_SV ,yerr= del_L_SV, ecolor='pink')
# plt.errorbar(T_eff_RW,L_RW, xerr = del_T_RW ,yerr= del_L_RW, ecolor='cyan')
plt.errorbar(T_eff_KN,L_KN, xerr = del_T_KN ,yerr= del_L_KN, ecolor='k', elinewidth=40)

#####Labels
plt.xlabel('Log T_eff (K)' ,color = 'k', fontsize = '28')
plt.ylabel('Log L (Solar Luminosity)',color = 'k', fontsize = '28')
plt.tick_params(axis = 'x' ,colors = 'w')
plt.tick_params(axis = 'y' ,colors = 'w')
axes.set_facecolor("w")
fig.set_facecolor('w')
# plt.title('Merged KN Cen',color = 'white')
# plt.legend(loc = 'upper left')
plt.xticks(fontsize = 28);
plt.yticks(fontsize = 28);
# plt.xlim(4,3.6)
# plt.ylim(3.5,3.75)
