# %%
import mesa_reader as mr
import matplotlib.pyplot as plt
import numpy as np
History_file_6_75M = mr.MesaData('/home/sprasadh/general_6_75M/general/work/LOGS/history.data')
temp_6_75M = History_file_6_75M.data('Teff')
temp_6_75M = np.log10(temp_6_75M)
Lum_6_75M = History_file_6_75M.data('log_L')
ages_6_75M = History_file_6_75M.data('star_age')


History_file_7_75M = mr.MesaData('/home/sprasadh/general_7_75M/general/work/LOGS/history.data')
temp_7_75M = History_file_7_75M.data('Teff')
temp_7_75M = np.log10(temp_7_75M)
Lum_7_75M = History_file_7_75M.data('log_L')
ages_7_75M = History_file_7_75M.data('star_age')


History_file_9_25M = mr.MesaData('/home/sprasadh/general_9_25M/general/work/LOGS/history.data')
temp_9_25M = History_file_9_25M.data('Teff')
temp_9_25M = np.log10(temp_9_25M)
Lum_9_25M = History_file_9_25M.data('log_L')
ages_9_25M = History_file_9_25M.data('star_age')
History_file_6_5M_CCO = mr.MesaData('/home/sprasadh/Convective_Core_Overshooting/general_6_5M/general/work/LOGS/history.data')
temp_6_5M_CCO = History_file_6_5M_CCO.data('Teff')
temp_6_5M_CCO = np.log10(temp_6_5M_CCO)
Lum_6_5M_CCO = History_file_6_5M_CCO.data('log_L')
ages_6_5M_CCO = History_file_6_5M_CCO.data('star_age')


History_file_7_5M_CCO = mr.MesaData('/home/sprasadh/Convective_Core_Overshooting/general_7_5M/general/work/LOGS/history.data')
temp_7_5M_CCO = History_file_7_5M_CCO.data('Teff')
temp_7_5M_CCO = np.log10(temp_7_5M_CCO)
Lum_7_5M_CCO = History_file_7_5M_CCO.data('log_L')
ages_7_5M_CCO = History_file_7_5M_CCO.data('star_age')

History_file_9M_CCO = mr.MesaData('/home/sprasadh/Convective_Core_Overshooting/general_9M/general_7.5M/work/LOGS/history.data')
temp_9M_CCO = History_file_9M_CCO.data('Teff')
temp_9M_CCO = np.log10(temp_9M_CCO)
Lum_9M_CCO = History_file_9M_CCO.data('log_L')
ages_9M_CCO = History_file_9M_CCO.data('star_age')


History_file_6_25M_CCO_2 = mr.MesaData('/home/sprasadh/Higher_Overshooting/general_6_25M/general/work/LOGS/history.data')
temp_6_25M_CCO_2 = History_file_6_25M_CCO_2.data('Teff')
temp_6_25M_CCO_2 = np.log10(temp_6_25M_CCO_2)
Lum_6_25M_CCO_2 = History_file_6_25M_CCO_2.data('log_L')
ages_6_25M_CCO_2 = History_file_6_25M_CCO_2.data('star_age')


History_file_7_25M_CCO_2 = mr.MesaData('/home/sprasadh/Higher_Overshooting/general_7_25M/general/work/LOGS/history.data')
temp_7_25M_CCO_2 = History_file_7_25M_CCO_2.data('Teff')
temp_7_25M_CCO_2 = np.log10(temp_7_25M_CCO_2)
Lum_7_25M_CCO_2 = History_file_7_25M_CCO_2.data('log_L')
ages_7_25M_CCO_2 = History_file_7_25M_CCO_2.data('star_age')

History_file_8_75M_CCO_2 = mr.MesaData('/home/sprasadh/Higher_Overshooting/general_8_75M/general_7.5M/work/LOGS/history.data')
temp_8_75M_CCO_2 = History_file_8_75M_CCO_2.data('Teff')
temp_8_75M_CCO_2 = np.log10(temp_8_75M_CCO_2)
Lum_8_75M_CCO_2 = History_file_8_75M_CCO_2.data('log_L')
ages_8_75M_CCO_2 = History_file_8_75M_CCO_2.data('star_age')

P_KN = 34.029641
P_SV = 11.129318
P_RW = 16.414812

B_V_KN = 1.58
B_V_RW = 1.35
B_V_SV = 1.04

del_B_V = 0.02
B_V_CKN = -0.14
B_V_CRW = -0.08
B_V_CSV = -0.09

T_eff_CSV = 4.10
T_eff_CRW = 4.09
T_eff_CKN = 4.16


del_T_CSV = 0.005*T_eff_CSV
del_T_CRW = 0.005*T_eff_CRW
del_T_CKN = 0.005*T_eff_CKN
fie_SV = 0.716+ (0.225*B_V_SV)
fie_RW = 0.716+ (0.225*B_V_RW)
fie_KN = 0.716+ (0.225*B_V_KN)
del_fie_SV =  0.015+ (B_V_SV*0.017) + del_B_V*(0.225)
del_fie_RW =  0.015+ (B_V_RW*0.017) + del_B_V*(0.225)
del_fie_KN =  0.015+ (B_V_KN*0.017) + del_B_V*(0.225)
T_eff_SV = np.log10(5040/fie_SV)
T_eff_RW = np.log10(5040/fie_RW)
T_eff_KN = np.log10(5040/fie_KN)
del_T_SV_1= (del_fie_SV/fie_SV**2)
del_T_RW_1 = (del_fie_RW/fie_RW**2)
del_T_KN_1 = (del_fie_KN/fie_KN**2)
del_T_SV= (del_fie_SV/fie_SV**2)/T_eff_SV
del_T_RW = (del_fie_RW/fie_RW**2)/T_eff_RW
del_T_KN = (del_fie_KN/fie_KN**2)/T_eff_KN
a = -2.715
b = -4.153
P_SV = 11.1
P_RW = 16.2
P_KN = 34.4
M_v_SV = a*(np.log10(P_SV)-(np.log10(10))) + b
M_v_RW = a*(np.log10(P_RW)-(np.log10(10))) + b
M_v_KN = a*(np.log10(P_KN)-(np.log10(10))) + b
BC_SV = -0.161
BC_RW = -0.232
BC_KN = -0.161
del_P = 0.0001
M_bol_SV = M_v_SV + BC_SV
M_bol_RW = M_v_RW + BC_RW
M_bol_KN = M_v_KN + BC_KN
L_SV = (4.8-M_bol_SV)/2.5
L_RW = (4.8-M_bol_RW)/2.5
L_KN = (4.8-M_bol_KN)/2.5
del_beta = 0.060

del_Mv_SV = a*(del_P/P_SV) + del_beta
del_Mv_RW = a*(del_P/P_RW) + del_beta
del_Mv_KN = a*(del_P/P_KN) + del_beta

del_L_SV = (-M_bol_SV*del_Mv_SV)/2.5
del_L_RW = (-M_bol_RW*del_Mv_RW)/2.5
del_L_KN = (-M_bol_KN*del_Mv_KN)/2.5
L_CSV = 2.99
L_CRW = 3.11
L_CKN = 3.43

del_L_CSV = 0.02*L_CSV 
del_L_CRW = 0.02*L_CRW
del_L_CKN = 0.02*L_CKN
fig, ax = plt.subplots(1, figsize=(26, 16))

fontweight='bold'
#########Instability Strip
blue_left_edge = [3.91, 3.76]
blue_right_edge = [2.4, 4.5]
red_left_edge = [3.79, 3.65]
red_right_edge = [2.4, 4.5]

ax.plot(blue_left_edge, blue_right_edge, 'b')
ax.plot(red_left_edge, red_right_edge, 'r')
ax.invert_xaxis()

#######Companion
ax.plot(T_eff_CSV, L_CSV, marker='X', color='magenta', markersize=22)
ax.plot(T_eff_CRW, L_CRW, '^', color='green', markersize=22)
ax.plot(T_eff_CKN, L_CKN, 'P', color='darkslategrey', markersize=22)

#######Cepheid
ax.plot(T_eff_SV, L_SV, 'X', color='magenta', label='SV Per')
ax.plot(T_eff_RW, L_RW, '^', color='green', label='RW Cam')
ax.plot(T_eff_KN, L_KN, 'P', color='darkslategrey', label='KN Cen')

ax.errorbar(T_eff_SV, L_SV, xerr=del_T_SV, yerr=del_L_SV, ecolor='magenta', elinewidth=45)
ax.errorbar(T_eff_RW, L_RW, xerr=del_T_RW, yerr=del_L_RW, ecolor='green', elinewidth=45)
ax.errorbar(T_eff_KN, L_KN, xerr=del_T_KN, yerr=del_L_KN, ecolor='darkslategrey', elinewidth=45)

#####Labels
plt.xlabel(r'Log $T_{eff}$ (K)' ,color = 'k', fontsize = '28')
plt.ylabel(r'Log L (L$_{\odot}$)',color = 'k' , fontsize = '28')
ax.tick_params(axis='x', colors='k')
ax.tick_params(axis='y', colors='k')
ax.set_facecolor("w")
fig.set_facecolor('w')

plt.xticks(fontsize=28)
plt.yticks(fontsize=28)

plt.plot(temp_6_75M,Lum_6_75M ,color ='indigo')
plt.plot(temp_6_5M_CCO,Lum_6_5M_CCO ,color ='dodgerblue')
plt.plot(temp_6_25M_CCO_2,Lum_6_25M_CCO_2 ,color ='orangered')


plt.plot(temp_7_75M,Lum_7_75M ,color ='indigo')
plt.plot(temp_7_5M_CCO,Lum_7_5M_CCO ,color ='dodgerblue')
plt.plot(temp_7_25M_CCO_2,Lum_7_25M_CCO_2 ,color ='orangered')

plt.plot(temp_9_25M,Lum_9_25M ,color ='indigo')
plt.plot(temp_9M_CCO,Lum_9M_CCO ,color ='dodgerblue')
plt.plot(temp_8_75M_CCO_2,Lum_8_75M_CCO_2 ,color ='orangered')


ax.text(0.8105, 0.87, 'KN', horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.8105, 0.845, 'CEN', horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.788, 0.72,'RW' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.7865, 0.69,'CAM' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.755, 0.62,'SV' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)
ax.text(0.755, 0.60,'PER' , horizontalalignment='center', verticalalignment='center', fontsize=20, transform=ax.transAxes, color = 'w', fontweight = fontweight)



ax.text(0.10, 0.381, r'6.75 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'indigo')
ax.text(0.11, 0.345, r'6.5 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'teal')
ax.text(0.13, 0.315, r'6.25 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'orangered')

ax.text(0.06, 0.4751, r'7.75 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'indigo')
ax.text(0.065, 0.45, r'7.5 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'teal')
ax.text(0.07, 0.42, r'7.25 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'orangered')

ax.text(0.033, 0.61, r'9.25 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'indigo')
ax.text(0.03, 0.57, r'9 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'teal')
ax.text(0.04, 0.535, r'8.75 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'orangered')

ax.text(0.325, 0.479, r'6.5 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'darkslategrey')
ax.text(0.40, 0.355, r'5.5 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'green')
ax.text(0.396, 0.29, r'4.75 M$_{\odot}$', horizontalalignment='center', verticalalignment='center', fontsize=24, transform=ax.transAxes, color = 'magenta')
## Ages
Blue_loop_6_5M_CCO_SV = int(len(temp_6_5M_CCO)*(0.6))
min_7_5left_SV = Blue_loop_6_5M_CCO_SV + np.argmin(np.abs(temp_6_5M_CCO[Blue_loop_6_5M_CCO_SV:] - (T_eff_SV + del_T_SV))) 
Age_7_5left_SV = ages_6_5M_CCO[min_7_5left_SV]

min_7_5right_SV = Blue_loop_6_5M_CCO_SV + np.argmin(np.abs(temp_6_5M_CCO[Blue_loop_6_5M_CCO_SV:] - (T_eff_SV - del_T_SV))) 
Age_7_5right_SV = ages_6_5M_CCO[min_7_5right_SV]

print(Age_7_5left_SV)
print(Age_7_5right_SV)
Blue_loop_6_25M_CCO_SV = int(len(temp_6_25M_CCO_2)*(0.6))
min_6_25left_SV = Blue_loop_6_25M_CCO_SV + np.argmin(np.abs(temp_6_25M_CCO_2[Blue_loop_6_25M_CCO_SV:] - (T_eff_SV + del_T_SV))) 
Age_6_25left_SV = ages_6_25M_CCO_2[min_6_25left_SV]

min_6_25right_SV = Blue_loop_6_25M_CCO_SV + np.argmin(np.abs(temp_6_25M_CCO_2[Blue_loop_6_5M_CCO_SV:] - (T_eff_SV - del_T_SV))) 
Age_6_25right_SV = ages_6_25M_CCO_2[min_6_25right_SV]

print(Age_6_25left_SV)
print(Age_6_25right_SV)
Blue_loop_7_5_CCO_RW = int(len(temp_7_5M_CCO)*(0.6))
min_7_5_CCOleft_RW = Blue_loop_7_5_CCO_RW + np.argmin(np.abs(temp_7_5M_CCO[Blue_loop_7_5_CCO_RW:] - (T_eff_RW + del_T_RW))) 
Age_7_5_CCOleft_RW = ages_7_5M_CCO[min_7_5_CCOleft_RW]

min_7_5_CCOright_RW = Blue_loop_7_5_CCO_RW + np.argmin(np.abs(temp_7_5M_CCO[Blue_loop_7_5_CCO_RW:] - (T_eff_RW - del_T_RW))) 
Age_7_5_CCOright_RW = ages_7_5M_CCO[min_7_5_CCOright_RW]

print(Age_7_5_CCOleft_RW)
print(Age_7_5_CCOright_RW)
Blue_loop_7_25_CCO_RW = int(len(temp_7_25M_CCO_2)*(0.6))
min_7_25_CCOleft_RW = Blue_loop_7_25_CCO_RW + np.argmin(np.abs(temp_7_25M_CCO_2[Blue_loop_7_25_CCO_RW:] - (T_eff_RW + del_T_RW))) 
Age_7_25_CCOleft_RW = ages_7_25M_CCO_2[min_7_25_CCOleft_RW]

min_7_25_CCOright_RW = Blue_loop_7_25_CCO_RW + np.argmin(np.abs(temp_7_25M_CCO_2[Blue_loop_7_25_CCO_RW:] - (T_eff_RW - del_T_RW))) 
Age_7_25_CCOright_RW = ages_7_25M_CCO_2[min_7_25_CCOright_RW]

print(Age_7_25_CCOleft_RW)
print(Age_7_25_CCOright_RW)

Blue_loop_9_25M_KN = int(len(temp_9_25M)*(0.6))
min_9_25left_KN = Blue_loop_9_25M_KN + np.argmin(np.abs(temp_9_25M[Blue_loop_9_25M_KN:] - (T_eff_KN + del_T_KN))) 
Age_9_25left_KN = ages_9_25M[min_9_25left_KN]

min_9_25right_KN = Blue_loop_9_25M_KN + np.argmin(np.abs(temp_9_25M[Blue_loop_9_25M_KN:] - (T_eff_KN - del_T_KN))) 
Age_9_25right_KN = ages_9_25M[min_9_25right_KN]

print(Age_9_25left_KN)
print(Age_9_25right_KN)

Blue_loop_9M_CCO_KN = int(len(temp_9M_CCO)*(0.6))
min_9left_KN = Blue_loop_9M_CCO_KN + np.argmin(np.abs(temp_9M_CCO[Blue_loop_9M_CCO_KN:] - (T_eff_KN + del_T_KN))) 
Age_9left_KN = ages_9M_CCO[min_9left_KN]

min_9right_KN = Blue_loop_9M_CCO_KN + np.argmin(np.abs(temp_9M_CCO[Blue_loop_9M_CCO_KN:] - (T_eff_KN - del_T_KN))) 
Age_9right_KN = ages_9M_CCO[min_9right_KN]

print(Age_9left_KN)
print(Age_9right_KN)
Blue_loop_8_75M_CCO_2_KN = int(len(temp_8_75M_CCO_2)*(0.6))
min_8_75left_KN = Blue_loop_8_75M_CCO_2_KN + np.argmin(np.abs(temp_8_75M_CCO_2[Blue_loop_8_75M_CCO_2_KN:] - (T_eff_KN + del_T_KN))) 
Age_8_75left_KN = ages_8_75M_CCO_2[min_8_75left_KN]

min_8_75right_KN = Blue_loop_8_75M_CCO_2_KN + np.argmin(np.abs(temp_8_75M_CCO_2[Blue_loop_8_75M_CCO_2_KN:] - (T_eff_KN - del_T_KN))) 
Age_8_75right_KN = ages_8_75M_CCO_2[min_8_75right_KN]

print(Age_9left_KN)
print(Age_9right_KN)
